# %% [markdown]
# # Prompt Optimization with DSPy
#
# <a target="_blank" href="https://colab.research.google.com/github/deepset-ai/haystack-cookbook/blob/main/notebooks/prompt_optimization_with_dspy.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" width="200" alt="Open In Colab"/>
# </a>
#
# <img src="https://raw.githubusercontent.com/stanfordnlp/dspy/main/docs/images/DSPy8.png" width="400" style="display:inline;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://haystack.deepset.ai/images/haystack-ogimage.png" width="430" style="display:inline;">
#
# When building applications with LLMs, writing effective prompts is a long process of trial and error.
# Often, if you switch models, you also have to change the prompt.
# What if you could automate this process?
#
# That's where **DSPy** comes in - a framework designed to algorithmically optimize prompts for Language Models.
# By applying classical machine learning concepts (training and evaluation data, metrics, optimization), DSPy generates better prompts for a given model and task.
#
# In this notebook, we will see **how to combine DSPy with the robustness of Haystack Pipelines**.
# - ▶️ Start from a Haystack RAG pipeline with a basic prompt
# - 🎯 Define a goal (in this case, get correct and concise answers)
# - 📊 Create a DSPy program, define data and metrics
# - ✨ Optimize and evaluate -> improved prompt
# - 🚀 Build a refined Haystack RAG pipeline using the optimized prompt

# %% [markdown]
# >[Prompt Optimization with DSPy](#scrollTo=OWWPapD1mhqs)
#
# >>[Setup](#scrollTo=S-j3AJ3lne-o)
#
# >>[Load data](#scrollTo=45hUq3KCp-bG)
#
# >>[Initial Haystack pipeline](#scrollTo=eTy01somr_xl)
#
# >>[DSPy](#scrollTo=mZQd-J9zzpCF)
#
# >>>[DSPy Signature](#scrollTo=QzUT-Nqc1GRp)
#
# >>>[DSPy RAG module](#scrollTo=dmee88jC29qp)
#
# >>>[Create training and dev sets](#scrollTo=yX1q7a_J5YgP)
#
# >>>[Define a metric](#scrollTo=JRjG8dPU8dpp)
#
# >>>[Evaluate unoptimized RAG module](#scrollTo=eQX9ypSN-cEU)
#
# >>>[Optimization](#scrollTo=qOJRB6h6_SHE)
#
# >>>[Evaluate optimized RAG module](#scrollTo=4aa2dU0BAngE)
#
# >>>[Inspect the optimized prompt](#scrollTo=VgADv_j2BObc)
#
# >>[Optimized Haystack Pipeline](#scrollTo=ZSn00x5FBisv)

# %% [markdown]
# ## Setup

# %%
! pip install haystack-ai datasets dspy-ai sentence-transformers
# Out:
# Requirement already satisfied: haystack-ai in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (2.3.0)
# Collecting datasets
#   Using cached datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting dspy-ai
#   Downloading dspy_ai-2.4.12-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: sentence-transformers in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (2.7.0)
# Requirement already satisfied: haystack-experimental in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (0.1.0)
# Requirement already satisfied: jinja2 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (3.1.4)
# Requirement already satisfied: lazy-imports in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (0.3.1)
# Requirement already satisfied: more-itertools in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (10.3.0)
# Requirement already satisfied: networkx in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (3.3)
# Requirement already satisfied: numpy<2 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (1.30.4)
# Requirement already satisfied: pandas in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (1.5.3)
# Requirement already satisfied: posthog in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (3.5.0)
# Requirement already satisfied: python-dateutil in c:\users\sri.karan\appdata\roaming\python\python310\site-packages (from haystack-ai) (2.9.0.post0)
# Requirement already satisfied: pyyaml in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (6.0.1)
# Requirement already satisfied: requests in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (8.3.0)
# Requirement already satisfied: tqdm in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from haystack-ai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sri.karan\appdata\roaming\python\python310\site-packages (from haystack-ai) (4.12.0)
# Requirement already satisfied: filelock in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from datasets) (3.14.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from datasets) (16.1.0)
# Collecting pyarrow-hotfix (from datasets)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2024.5.0)
# Requirement already satisfied: aiohttp in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: backoff in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from dspy-ai) (2.2.1)
# Collecting joblib<=1.3.2 (from dspy-ai)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting optuna (from dspy-ai)
#   Using cached optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic~=2.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from dspy-ai) (2.7.2)
# Requirement already satisfied: regex in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from dspy-ai) (2024.5.15)
# Collecting structlog (from dspy-ai)
#   Downloading structlog-24.4.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: ujson in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from dspy-ai) (5.10.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sentence-transformers) (4.41.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: scikit-learn in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from openai>=1.1.0->haystack-ai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from openai>=1.1.0->haystack-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from openai>=1.1.0->haystack-ai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from openai>=1.1.0->haystack-ai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from pydantic~=2.0->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from pydantic~=2.0->dspy-ai) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from requests->haystack-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from requests->haystack-ai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from requests->haystack-ai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from requests->haystack-ai) (2024.2.2)
# Requirement already satisfied: sympy in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\sri.karan\appdata\roaming\python\python310\site-packages (from tqdm->haystack-ai) (0.4.6)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from jinja2->haystack-ai) (2.1.5)
# Collecting alembic>=1.5.0 (from optuna->dspy-ai)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->dspy-ai)
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from optuna->dspy-ai) (1.4.48)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from pandas->haystack-ai) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sri.karan\appdata\roaming\python\python310\site-packages (from python-dateutil->haystack-ai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from posthog->haystack-ai) (1.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Collecting Mako (from alembic>=1.5.0->optuna->dspy-ai)
#   Using cached Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sri.karan\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->haystack-ai) (1.2.1)
# Requirement already satisfied: httpcore==1.* in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai) (0.14.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sqlalchemy>=1.3.0->optuna->dspy-ai) (3.0.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sri.karan\.conda\envs\rag\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ---------------------------------------- 0.0/547.8 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/547.8 kB 1.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 225.3/547.8 kB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 409.6/547.8 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 547.8/547.8 kB 3.1 MB/s eta 0:00:00
# Downloading dspy_ai-2.4.12-py3-none-any.whl (276 kB)
#    ---------------------------------------- 0.0/276.3 kB ? eta -:--:--
#    -------------------------------------- - 266.2/276.3 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 276.3/276.3 kB 4.3 MB/s eta 0:00:00
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached optuna-3.6.1-py3-none-any.whl (380 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading structlog-24.4.0-py3-none-any.whl (67 kB)
#    ---------------------------------------- 0.0/67.2 kB ? eta -:--:--
#    ---------------------------------------- 67.2/67.2 kB 3.6 MB/s eta 0:00:00
# Using cached xxhash-3.4.1-cp310-cp310-win_amd64.whl (29 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/233.0 kB ? eta -:--:--
#    ---------------------------------------- 233.0/233.0 kB 7.2 MB/s eta 0:00:00
# Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached Mako-1.3.5-py3-none-any.whl (78 kB)
# Installing collected packages: xxhash, structlog, pyarrow-hotfix, Mako, joblib, dill, colorlog, multiprocess, alembic, optuna, datasets, dspy-ai
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 datasets-2.20.0 dill-0.3.8 dspy-ai-2.4.12 joblib-1.3.2 multiprocess-0.70.16 optuna-3.6.1 pyarrow-hotfix-0.6 structlog-24.4.0 xxhash-3.4.1

# %%
import os
from getpass import getpass
from rich import print

from dotenv import load_dotenv
load_dotenv()

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter OpenAI API key:")

# %% [markdown]
# ## Load data
#
# We will use the first 1000 rows of a [labeled PubMed dataset](https://huggingface.co/datasets/vblagoje/PubMedQA_instruction/viewer/default/train?row=0) with questions, contexts and answers.
#
# Initially, we will use only the contexts as documents and write them to a Document Store.
#
# (Later, we will also use the questions and answers from a small subset of the dataset to create training and dev sets for optimization.)

# %%
from datasets import load_dataset
from haystack import Document

dataset = load_dataset("vblagoje/PubMedQA_instruction", split="train")
dataset = dataset.select(range(1000))
# Out:
# Downloading readme:   0%|          | 0.00/498 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/274M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/986k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/272458 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['instruction', 'context', 'response', 'category'],
#     num_rows: 1000
# })

# %%
print(dataset["instruction"][0]),print(dataset["context"][0]),print(dataset["response"][0])
# Out:
# Are group 2 innate lymphoid cells ( ILC2s ) increased in chronic rhinosinusitis with nasal polyps or eosinophilia?
# Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 innate lymphoid
# cells (ILC2s) represent a recently discovered cell population which has been implicated in driving Th2 inflammation
# in CRS; however, their relationship with clinical disease characteristics has yet to be investigated. The aim of
# this study was to identify ILC2s in sinus mucosa in patients with CRS and controls and compare ILC2s across
# characteristics of disease. A cross-sectional study of patients with CRS undergoing endoscopic sinus surgery was
# conducted. Sinus mucosal biopsies were obtained during surgery and control tissue from patients undergoing
# pituitary tumour resection through transphenoidal approach. ILC2s were identified as CD45(+) Lin(-) CD127(+) CD4(-)
# CD8(-) CRTH2(CD294)(+) CD161(+) cells in single cell suspensions through flow cytometry. ILC2 frequencies, measured
# as a percentage of CD45(+) cells, were compared across CRS phenotype, endotype, inflammatory CRS subtype and other
# disease characteristics including blood eosinophils, serum IgE, asthma status and nasal symptom score. 35 patients
# (40% female, age 48 ± 17 years) including 13 with eosinophilic CRS (eCRS), 13 with non-eCRS and 9 controls were
# recruited. ILC2 frequencies were associated with the presence of nasal polyps (P = 0.002) as well as high tissue
# eosinophilia (P = 0.004) and eosinophil-dominant CRS (P = 0.001) (Mann-Whitney U). They were also associated with
# increased blood eosinophilia (P = 0.005). There were no significant associations found between ILC2s and serum
# total IgE and allergic disease. In the CRS with nasal polyps (CRSwNP) population, ILC2s were increased in patients
# with co-existing asthma (P = 0.03). ILC2s were also correlated with worsening nasal symptom score in CRS (P =
# 0.04).
# As ILC2s are elevated in patients with CRSwNP, they may drive nasal polyp formation in CRS. ILC2s are also linked
# with high tissue and blood eosinophilia and have a potential role in the activation and survival of eosinophils
# during the Th2 immune response. The association of innate lymphoid cells in CRS provides insights into its
# pathogenesis.
# (None, None, None)

# %%
docs = [Document(content=doc["context"]) for doc in dataset]

# %%
docs
# Out:
# [Document(id=f6fde0752a035f7a15860dfa6c45d3ee05380198f18abf43b7b4923ec44c9985, content: 'Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 inna...'),
#  Document(id=8889ef27dbfe0b3cc5ba24652b393fc9e39cd49d21db1b7dbeb8a79363b4fb12, content: 'Phosphatidylethanolamine N-methyltransferase (PEMT), a liver enriched enzyme, is responsible for app...'),
#  Document(id=699ac0bd51891960eb58709be9f2ffef41fcbc7ea51f247c7b922e3ad1e358c3, content: 'Psammaplin A (PsA) is a natural product isolated from marine sponges, which has been demonstrated to...'),
#  Document(id=8c714387bf3999ef9b3e11997d8dc5f894ee2ffc281202db4c1a66faf65e5752, content: 'This study examined links between DNA methylation and birth weight centile (BWC), and explored the i...'),
#  Document(id=7a59e616dab6b59e767513a13b3cd3551843c52d3349c1fd2a6c827b9885912c, content: 'Tumor microenvironment immunity is associated with breast cancer outcome. A high lymphocytic infiltr...'),
#  Document(id=1a4828553b643a97e81390c9cba10d13fd92cf58de6bf79008a6641a709f4b02, content: 'Hidradenitis suppurativa (HS) is a chronic inflammatory disease involving intertriginous skin. Previ...'),
#  Document(id=d93504956be79f37583fb09bba3b01075eb19f0ef02c6cf4be24fc2897435e45, content: 'The interassay variability found in the measurement of testosterone (T) levels warrants the need for...'),
#  Document(id=c18ec704644151302b72d2fb119269df52c035d09f5a1e7183bfff4310d83ac2, content: 'Secretory phospholipases A2 (sPLA2) initiate the biosynthesis of eicosanoids, are increased in the a...'),
#  Document(id=a9f6958482f17c11c5d3330121bafa8531ae939cb2afb68bdf92e26a74f17de0, content: 'Hyperglycemia on admission is associated with increased mortality rates in patients with ST-elevatio...'),
#  Document(id=fe941e151c42633ed54a808b842004b3ec3329de83ee0a8d5fcfeb188c8b04d4, content: 'Publication bias compromises the validity of systematic reviews. This problem can be addressed in pa...'),
#  Document(id=2079247fdd8b0987a3f60dd5e845ea807024d86fb5f4d213472fda62d72c9732, content: 'Obese patients with idiopathic pulmonary fibrosis (IPF) have higher 90-day mortality after lung tran...'),
#  Document(id=7963e38102b44304bb7f04b31ba28dac38d676974157255bf0f5759431cf7aeb, content: 'Schizophrenia is recognized as a disorder of the brain and neuronal connectivity. The neural cell ad...'),
#  Document(id=ee4b890b9db8d625dfb21c1c69f556a23f1698010eb74f1d55e47593d32b2083, content: 'Oxidative stress generated within inflammatory joints can produce autoimmune phenomena and joint des...'),
#  Document(id=dc39813296ba3042aa82d50026aa4ba5291b4dd99220d78c8154a36117471ffd, content: 'Activation of B cells is a hallmark of systemic lupus erythematosus (SLE). Syk and TRAF6 are key sig...'),
#  Document(id=066a566efdd1ad28525965a8e0316abd255c4baa3665e22431ca8a63a3a919b6, content: 'The aim of this study was to determine the reasons for which erupted third molars (3M) are extracted...'),
#  Document(id=8c5683287deffb92320fdf53e40bf2421e2809ce5d5442910c3fef04ec18369b, content: 'To measure the through-focus curve for eyes implanted with a type 1 Boston keratoprosthesis (KPro) a...'),
#  Document(id=85cb7e6d9beb86aa49b6d9c76ae545cc1ea083211610d1b33a9d216eef9de60e, content: 'Larger food portions lead to increased intake but the mechanism behind this effect is unclear. We in...'),
#  Document(id=47e723a092c6d98fd20215212ef74df40d917e0dcd22925b1305f4a495eacd87, content: 'Pre-operative restaging CT scans are often performed routinely following neoadjuvant chemoradiothera...'),
#  Document(id=c3c7302b197dad6559da8b1cf6b653f974bd7187b85ca4a3f83b576ba2afd6b5, content: 'Plasma levels of pancreatic polypeptide (PP) rise upon food intake. Although other pancreatic islet ...'),
#  Document(id=8024af6729b63ecf4e0cce06999ae5d37d4047d79b4f1de0c837e5e65356d660, content: 'To review UK newspaper reports relating to Do Not Attempt Cardiopulmonary Resuscitation (DNACPR) dec...'),
#  Document(id=9ed854a7f0e92a221633010878b982f3d532e0ae4a854ef4841ea91baa2264c8, content: 'The interval between neoadjuvant chemoradiation treatment and surgery has been described as an impor...'),
#  Document(id=120042248aff1af25f77ef99bbfa92764aa8ed41cb8d9f168ec69e2006cd6067, content: 'To investigate whether epileptogenic focus localization is possible based on resting state connectiv...'),
#  Document(id=8a6dbabf1ad302c244e3c3c8e907dd3bb9184b002d342992d44a5672e9075e75, content: 'To assess the effect of treatment of seminal Helicobacter pylori in infertile asthenozoospermic men....'),
#  Document(id=b6ead0cfdb500352d11da10f5643072e205952f30da22613dc22f4537b4dc7f5, content: 'In most cells, the cilium is formed within a compartment separated from the cytoplasm. Entry into th...'),
#  Document(id=7b2ab2daf2fde179c48ea129a0f9c9654b375e9e803b32e8e98f5c36844656a1, content: 'Active commuters have lower risk of chronic disease. Understanding which of the, to some extent, mod...'),
#  Document(id=56c576350e8790edd86c58626143cfec27c40cbce910e1b2820035a0e75b2976, content: 'Pathophysiological mechanisms leading to chordee in patients with hypospadias and to the hidden stat...'),
#  Document(id=1088582518699fcae037c4e048a1cd25130c34970cc83012cf9dac418d9ce2c9, content: 'Several risk factors have been claimed to predict the progression of clinically high grade T1 bladde...'),
#  Document(id=9928bb3fd5bfd294a30717df6f590301c0f7c82f65fec5ff9ae7a00ac4956571, content: 'To date, no data is available about procalcitonin (PCT) levels and its relevance to morbidity and gr...'),
#  Document(id=b6e9dafd18e4f58907992016a03e66164467e2f8da908ea03a2fdc801b645efe, content: 'The purpose of this study was to assess liver-type fatty acid-binding protein (L-FABP) expression an...'),
#  Document(id=2a259dcae244aec3c3a3592619bb07c9b45d2c6ea6576b1fe6a76c005e5f540c, content: 'Vein bypass is an essential therapy for patients with advanced peripheral and coronary artery diseas...'),
#  Document(id=e915253b0cee8ab0cab6f7806b4fa53afdf14142b1175bf0a543d3e890bd7b0f, content: 'Low serum levels of vitamin D have been associated with depression in non-stroke subjects. Our aim w...'),
#  Document(id=c139f6e0955916d7af4b2b24f05f3484edc652e89581219a67d8d672b6afbac7, content: 'Barrett's esophagus (BE) increases the risk of esophageal adenocarcinoma (EAC). We found the risk to...'),
#  Document(id=a82c1fd7f9cbf98d4bbbc8d4e1886a2108389fa44433fb2b09f6c18717a9e2c7, content: 'Danzhi Xiaoyao San (DXS) is a canonical Chinese medicine formula from Principles of Internal Medicin...'),
#  Document(id=5cd6e9799eea146dba9ad74fc8bbeeea31735242f3d38b38546f180deebaadb2, content: 'Prostate cancer is the world's leading cause of cancer and the second cause of cancer-related death ...'),
#  Document(id=7b64c709a40ffc325c4ef18a0d22cd9b12d74209dad337d9a5bb1c3cb83769a8, content: 'Disturbed sleep is associated with mood disorders. Both depression and insomnia may increase the ris...'),
#  Document(id=dfef98047ce9246bf78d7e64d54bb297de5e0fdd821a3627e82f20f4c4898561, content: 'Phospholipase C epsilon 1 (PLCE1) plays a crucial role in carcinogenesis and progression of several ...'),
#  Document(id=f29fe995ac7257918364f138a4d242e91e6c2ff428a7dd60fcb7b8b764decc87, content: 'Esophageal squamous cell carcinoma (ESCC) is an important cause of cancer-related death worldwide. T...'),
#  Document(id=0d11c62d3675320aecce9f49fde191d4e95bbadc7b405a45a43958856d732597, content: 'Chronic antibiotic-refractory pouchitis (CARP) occurs more frequently in patients with ileal pouch-a...'),
#  Document(id=e4d83f8ac3c1b8f36ebe4bd8ac84eff1f8f2acd1d69b67e15b885c6a73b4326f, content: 'Alternating hemiplegia of childhood and rapid-onset dystonia parkinsonism are two separate movement ...'),
#  Document(id=7294f13010a15697d54ec95756b179aa6722c34d74acf6b0fdb301baa1ac3030, content: 'The principal oxidative-stress defense in the human parasite Trypanosoma cruzi is the tryparedoxin-d...'),
#  Document(id=2199fac205be97c1f4f9edd89c9e7dbe526d44102c75aecbdf37d909dfb650eb, content: 'The role of Kdr (VEGFR-2/Flk-1) in vascular formation has been well described, but the role of Flt1 ...'),
#  Document(id=b064af26dfbaa2bb9f219b2096224baf2012e9050af39687b96c91261d251599, content: 'The capacity of toll-like receptor (TLR) 7/8 agonist-conjugated hepatitis B virus (HBV) proteins (HB...'),
#  Document(id=510150de57b5bd2be72b598ac8fb8b30a418de0a960f290a535f293400bc72be, content: 'Normal aging is associated with a decline in cognitive abilities, particularly in the domains of psy...'),
#  Document(id=0ecdb4ae1ba3c9451931bbb6022c6c251acd72478de22a908ccf4755153b994d, content: 'In recent years, the relationship between physical activity (PA) and smoking cessation has been incr...'),
#  Document(id=9acecb19e0f03b84c97b4934c8a2b7c4b95c84ca8626a5ba98181d206b97ec32, content: 'Many assume that most patients hospitalized with heart failure (HF) are short of breath at rest (SOB...'),
#  Document(id=bd3582364dcb641ee9772d25130efb16e1815ec1cacab0e9e68ba2519daf2b5f, content: 'Duodenal stump disruption remains one of the most dreadful postgastrectomy complications, posing an ...'),
#  Document(id=ad480e67b38431205188a67d68ce777ce162ff010111b0e0e1f13ff778c05fbf, content: 'Elevated lipoprotein-associated phospholipase A2 (Lp-PLA2) levels are associated with both coronary ...'),
#  Document(id=e9ef501bd93bd4f5caf66a372abec440a6dc9276077c741570fdddf38f23f292, content: 'Recently, the role of osteoprotegerin (OPG) in the pathogenesis of heart failure through different m...'),
#  Document(id=f62089ea322013e84059c0c629c20c7f4e82ef6c2dd43bca77fd2760c8f12dbb, content: 'Burns are common and recurrent events treated by physicians on a daily basis at most emergency rooms...'),
#  Document(id=088d2af3f64c71e50fc18192e30090901dd40164d25bb5619f83bbefa2ee90f8, content: 'The goal of this study was to identify genetic determinants of plasma N-terminal proatrial natriuret...'),
#  Document(id=2595e0cf041de65875f256ab593de278d6aaff8f3e7e6babdc4b45b850bf7dda, content: 'Mycobacterium abscessus has emerged as a major pathogen in cystic fibrosis (CF) patients and has bee...'),
#  Document(id=aac58e638b3fd9b2d6f6a424b99b49a9e56d20eadad11b7d4bc0d89e9af580ec, content: 'Bacterial vaginosis is a risk factor for preterm birth. The various conventional methods for its dia...'),
#  Document(id=b8042889c0d99fb499a48978a7b2df28e6001b34f0727e2cb2136cb4db858cbf, content: 'Extranodal natural killer/T-cell lymphoma, nasal type (ENKTL), is an aggressive type of lymphoma who...'),
#  Document(id=3446d5e15fa1928cb582e8850b59f984e23d3aa14c1dcba7fe424a32b1afd566, content: 'To observe the therapeutic effects of continuous plasma filtration absorption (CPFA) treatment on bu...'),
#  Document(id=8e511fd7544c7fd1efec8cfceb698de030ac97605688f2cb0b7ef6892d498980, content: 'Studies performed in Andean populations living in high altitude, indicate that the reduced availabil...'),
#  Document(id=14307d83e9e4df1fb73893904ba878ed9a0498fd7121f37df33a2b718619f3dc, content: 'The aim of this study was to determine the association between 25-hydroxyvitamin D (25(OH)D) and neu...'),
#  Document(id=1037e6ce430001a4091d72efbe7d1626f9c0dcae4ce1ede59269c5bbd241694a, content: 'The aims of this study were to demonstrate the tumorigenicity of CD133+ colon cancer cells in vitro,...'),
#  Document(id=45d2d64d4555bbddde347e45fd16262faba97a2f2f8efcf33ef337dda01f82c0, content: 'Traumatic brain injury (TBI) affects millions of people each year and is characterized by direct tis...'),
#  Document(id=03c9ab140001f84387e45c5f4a937655de988ec7ce73d6fa56a457b5ac573dd5, content: 'To determine the effects of maternal undernutrition (MUN) on the reproductive axis of aging offsprin...'),
#  Document(id=c439d40b23a1e280e5146b9b202ab30e3490484cc9630447ed467e065e543462, content: 'To determine whether granulocyte colony-stimulating factor (G-CSF) could prevent loss of spermatogen...'),
#  Document(id=eb9683fa65e69da7a1268b1647a760d5d072636550582e520d6439f687dce11c, content: 'A vaccine against hepatitis C virus (HCV) is unavailable and cost-effective antivirals that prevent ...'),
#  Document(id=2f1be411b8673646b72551e57af84872e39a788c3602c9b22af2ae901eda0da4, content: 'Intrahepatic cholestasis of pregnancy (ICP) is defined by pruritus, elevated total fasting serum bil...'),
#  Document(id=a17ef1e38e49f274f0f7ea5fa2f72f25bfc95d866e33d2da0c31318bf2e20fcd, content: 'Programs seek to expose trainees to research during residency. However, little is known in any forma...'),
#  Document(id=e6d440046946ac5a2a8e94fa8e48609cab7d831cd8ecbcadb90c45011c46ce57, content: 'Heterotopic ossification (HO) may occur after musculoskeletal trauma, traumatic brain injury, and to...'),
#  Document(id=9632d4554efb59ac07a5c649c8c9809312e1b75a52a080b229ac64c3134163e2, content: 'Restoration of posterior condylar offset during TKA is believed to be important to improving knee ki...'),
#  Document(id=4c4c664c690ea8c6672465883f8415d619206796c7d50031e71f98c31b1351e0, content: 'We sought to identify whether stable single nucleotide polymorphisms (SNPs) of various endocrine and...'),
#  Document(id=3df616bf74825a98c611c43042123d757e8c19330c45f738614660cf5c813269, content: 'Researchers studying the murine response to stress generally use mice housed under standard, nationa...'),
#  Document(id=4b9e3a3879c6c0a45ce83bbd866e815c3ecdaba50142d65e169146920ccefd39, content: 'The important functions of the meniscus are shock absorption, passive stabilization and load transmi...'),
#  Document(id=b928600e5f998c6fb1c037d0aee80ee479aba23a8b112bc447badb68e7818d8c, content: 'Protein arginine methyltransferase 5 (PRMT5), is thought to play a role in epigenetic reprogramming ...'),
#  Document(id=d42c09221bd9ed6525b6e6e333a8d6c3c8923428a23fdfea8dc0fce1101c728c, content: 'Minimally invasive retroperitoneoscopic surgery (MIS) for psoas abscess (PA) in patients with thorac...'),
#  Document(id=b05a9796734eee6d6a2e90b8ea37fe979008ad583d4940267ec39390fba303b9, content: 'To evaluate the thickness of cartilage at the posterior aspect of the medial and lateral condyle in ...'),
#  Document(id=2d14ced6a2b597216d7d1611a169fad8ba8f749ef102b742096ddca100efe6e6, content: 'To investigate the specific role of Frizzled-related protein (FRZB) and Secreted frizzled-related pr...'),
#  Document(id=24271d2b319d3f8ed6abf705db151110adaeeb6454b1b3c34b49ab626f846e41, content: 'Recently, pluripotency of induced pluripotent stem (iPS) cells has been displayed after producing ad...'),
#  Document(id=7bc02e5c3f6ca207c870d8886d7ede77ef43178bd999e0a236bf6a9c5ae60ba5, content: 'Several reports have indicated the benefits of the acute care surgery (ACS) model in surgical outcom...'),
#  Document(id=b112787486a85ff8086de3f2562d80497bc4cc76bc9d8cf9d3d5b3ee3b663975, content: 'Most hepatocellular carcinomas (HCCs) are associated with cirrhosis. Portal hypertension (PHT) and e...'),
#  Document(id=4576619b01c5819bf71731dec0f1605b7e63af7207b64fe7ff005244f9de8663, content: 'Assessment of the activity of thioridazine towards Mycobacterium tuberculosis (Mtb), in vitro and in...'),
#  Document(id=9c56be74140f43fc2786a919628d4354666a110bbe37f1e817f1d09aa1329fb7, content: 'The prevalence of obesity in children is high, and many do not meet physical activity recommendation...'),
#  Document(id=06e848fa735ceee5cf1909c11a5cda242459ba3071b35d068cc9605ef399f3c7, content: 'Stroke is the third leading cause of invalidism and death in industrialized countries. There are con...'),
#  Document(id=288b11ea3e085f77fbefdb4492465fe0e6856dd948223fce146ad00fa8a3e744, content: 'Genetic haploinsufficiency of SYNGAP1/Syngap1 commonly occurs in developmental brain disorders, such...'),
#  Document(id=d8bc6a85ce9142c33519154ce517d3a5a349455bb8880140b19d09d3973cf5d5, content: 'Immunologic abnormalities have been found in bipolar disorder but pentraxin 3, a marker of innate im...'),
#  Document(id=6a7d0ed8c2f9b23cd623783640ae91547c198edef01bbfe45face558b69fff61, content: 'Convulsions associated with fever and acute onset of unknown aetiology with case fatalities have bec...'),
#  Document(id=051fe50ae6ab0bafaf88111968c2bf5c245e70659e688d10acc48cf8ecf2419c, content: 'Ex vivo heart perfusion (EVHP) provides the opportunity to resuscitate unused donor organs and facil...'),
#  Document(id=b1e65711f6b5a386199947e8b7d9a49f62950a5e880d02a72d359ca36b01d766, content: 'Immune monitoring (IM) has not been shown to be associated with cardiac allograft vasculopathy (CAV)...'),
#  Document(id=2c3b16458b359c2a190cc77f36c46ceb2c717192cf360d98ac8e7daadb8243b7, content: 'Poultry remains a major source of foodborne bacterial infections. A variety of additives with presum...'),
#  Document(id=54cf70fe1f6cb6422669431328e83c36367b4c5da987b85f3d2a7c3ea38bfcb5, content: 'Palmitate, a saturated fatty acid (FA), is known to induce toxicity and cell death in various types ...'),
#  Document(id=4304bcaeb472e6342c1959dcb8d62d206fe7939432af14117c0ab134aeecf0a4, content: 'In renal cell carcinoma (RCC), the prediction of metastasis via tumor prognostic markers remains a m...'),
#  Document(id=c82a66154481cb67f872a23efa5136693bdef870b698b92a1d9e3bb318006940, content: 'To compare optic nerve head (ONH) morphology between eyes with normal-tension glaucoma (NTG) and pri...'),
#  Document(id=7451ca239cbab1295b989b062c6d03b2a600108e5f0ff5dc994c04996a72564d, content: 'The aims of this study were to determine the effect of failed prior endovascular treatment (EV) on e...'),
#  Document(id=651a8a7d60bb0ab33d7f8ba91bc6e279d6a2c5f080b3866af85943480837d754, content: 'Guillotine below-knee amputation (BKA) for wet gangrene is an unfortunate complication of poorly con...'),
#  Document(id=8c758dba62958cb051f9b565cc21e20e6ecdccb7e9d4587c0d38e5f440ce2857, content: 'Remote renal ischemia-reperfusion injury (IRI) following infra-renal aortic occlusion leads to acute...'),
#  Document(id=58e49af93a6ad2c943eebf56b2009f29304c37befc71c5b7d92cc2b7b344c37d, content: 'Gene flow from crops to their wild relatives has the potential to alter population growth rates and ...'),
#  Document(id=830117a7853bb8f267a95dd576b5fefedc8038a092fd0e3b36b41d8817f0dabf, content: 'Progression from actinic keratosis (AK) to invasive squamous cell carcinoma (iSCC) of the skin is th...'),
#  Document(id=c87131b03e2874c06012abe803f22f5d5b6cf5b0b98cf9bf809d42e51f7257a6, content: 'Ascent to high altitude leads to a reduction in ambient pressure and a subsequent fall in available ...'),
#  Document(id=6b9ca632ef142e527ffdf28835218f7962a1fb971743dc776dd61895c9cf6301, content: 'To determine whether older adults with type 2 diabetes mellitus and cognitive dysfunction have poore...'),
#  Document(id=f22aafe80a657f45df46e5fbf158b60d2c212e3bf4e79898b8472904663a8a5b, content: 'To investigate whether serum anti-high mobility group box 1 (anti-HMGB1) antibodies are related to t...'),
#  Document(id=703fbd5c30134468175e780a6f1facde149ee75eaec8b9a7cefa4779ff69e442, content: 'Excessive consumption of ethanol is one of the most common causes of acute and chronic pancreatitis....'),
#  Document(id=c480b1762c6167c2e54411f912b0b911763ea9ef46f4b988e9a442910d4fc189, content: 'Flow-mediated dilation (FMD) is a complex mechanism involving several mediators, and different hemod...'),
#  Document(id=40d62e629b451f1676a0b814fb4fb9adad6f783a830a0360b11462ba4c9727de, content: 'Neutrophils can synthesize leukotriene B4 (LTB4) by activating the 5-lipoxygenase (5-LO)signaling pa...'),
#  Document(id=c8d70e4fa6236950d71425b33cf526b1304e183695cb2b863989046c55a71f52, content: 'The purpose of this study was to address the affects of mood modifying drugs on the transcriptome, i...'),
#  Document(id=3efa052b863edd7c1e4dee253b2feef19e3c5760348b1886d0a20dcb7a837aa0, content: 'Skeletal myoblasts fuse to form functional syncytial myotubes as an integral part of the skeletal mu...'),
#  Document(id=d0a94991ae302d42d4251ba95869d937dc56c1fad9ffa6da4c02dcca0dd6fc9a, content: 'Helminth-derived molecules are being identified as a new therapeutic approach for immune-mediated di...'),
#  Document(id=be8e6d4a0097e47e45fbcaa5965c4895186a5c7519161b3671b0c8992b948bea, content: 'The etiology of reduced left ventricular (LV) ejection fraction after exercise, without obstructive ...'),
#  Document(id=60470211158592d44cb16912a2777ab76724cd3c6f1cc6930e0c135531b954c8, content: 'The objective of this study was to examine the associations between objective measures of sleep dura...'),
#  Document(id=c61af27f4b20e2b98458259251ada6059e1614cd173496b075860801999e68f8, content: 'Morbidly obese patients usually present vitamin D deficiency or secondary hyperparathyroidism. Low v...'),
#  Document(id=b17349d9aad992b1c1f242597f1d2744410091dd9830ac45129c8fac694460ca, content: 'The optimal type of mesh for complex abdominal wall reconstruction has not been elucidated. We hypot...'),
#  Document(id=6cfc9c83f51c66300a1dc737964d4fc0bddeb979ca514bf8ac6d6bda08365262, content: 'Improper mechanical ventilation can exacerbate acute lung damage, causing a secondary ventilator-ind...'),
#  Document(id=087f63ff14b1885c57e5cea1aa784b5c3f18bb9c44963788c12bcba606f4f9bb, content: 'To prevent accidental ingestion of implant hex dive. Dental floss which is used to stabilize the hex...'),
#  Document(id=f9acf8395f7a13725956c7683e5b61dc8dbc68e03e3e4dd1230f1c46389a7d5e, content: 'A study was undertaken to identify the responsible gene defect underlying late onset spinal motor ne...'),
#  Document(id=085c5b7918cfd4ada0622eae3c3764988ff5965f6769f328caeae2de35d6a92b, content: 'In emergency cases, finger stick testing is primarily used to check the blood glucose value of patie...'),
#  Document(id=117e8228e8af6d1922d359de009e83f155291b1fb7fb3f685154dd9539f4f715, content: 'Hordeum vulgare L. (HV or barley) is used by traditional healers to treat various inflammatory and c...'),
#  Document(id=8a8a494b68c99f50bc24e7ded65acbb6566606e4877112f77945d31eba7cb114, content: 'To investigate the eff ect of intestinal trefoil factor (ITF) on the transcriptional activity of ITF...'),
#  Document(id=8e93b93b30acdee59437ca146471480355dc2e7db6b7a05a0c529e1081b5ac9d, content: 'To evaluate pazopanib eye drops in subjects with active subfoveal choroidal neovascularization (CNV)...'),
#  Document(id=9b1081a1d143bb47b6406d997e9631e003abf677ae748a5c3f98067bbac57452, content: 'Recent epidemiological evidence suggests that modifying lifestyle by increasing physical activity co...'),
#  Document(id=0f4bc9a3598d0e07e9ca615f1bed2d3e0c0ce44f607d0c3ba475b75dd72b6424, content: 'To evaluate the effect of an acute L-dopa administration on eye-closed resting state electroencephal...'),
#  Document(id=f0e2ee434223b0b08d3ef3346635c49faa4c7a85c78f840cd5cd5cfb173422e8, content: 'Limited data exist on the risk of developing cardiac sarcoidosis (CS) and/or adverse events in sarco...'),
#  Document(id=05fefccfefa4aa2357f4884fa015fff731a6dc79e9589142e9e3cde358f7aed3, content: 'Transposable elements form a significant proportion of eukaryotic genomes. Recently, Lexa et al. (Nu...'),
#  Document(id=b24d4ba27c7146e34ecc79bfe4ced0f13b995d84d665c7e6dbc7d1928504133d, content: 'Restenosis after vascular intervention remains a major clinical problem. Circulating LR11 has been s...'),
#  Document(id=060c98afed123503026323b5ae7c40aae1e6e2497f18e25c77ffdde5e6275edb, content: 'The development of human leukocyte antigen (HLA) antibody responses has been associated with worse c...'),
#  Document(id=899b54218bb4d7c550d00d9b744ebf0ab88df3b6e8f14ea5c23bcda4008fc9df, content: 'To conduct a systematic review of studies reporting on the development or validation of comorbidity ...'),
#  Document(id=383af746fb45dccd06bcd040eeb663ea42de5b2519290873d7567f03d3c4c417, content: 'The consumption of an agrarian diet is associated with a reduced risk for many diseases associated w...'),
#  Document(id=49bf7ed937f3f62dffbfeaa70f4998d2a39d836c9e28eb4bf85012a02d7d0fa4, content: 'Sox6 is a transcription factor that is crucial for the differentiation and development of cortical i...'),
#  Document(id=29b9656ff6306e0ba14ce44b7b908b061ae048659bdbc0cb7829a2f195df7c07, content: 'The purpose of this study was to evaluate the role of capsular closure after hip arthroscopy in redu...'),
#  Document(id=aad8405d6021d3ed73b1dc8a92c1d50b2c5f55e472b4a59df9b9888871f899b1, content: 'The purpose of this study was to examine the osteotomy gap filling rate with new bone after open wed...'),
#  Document(id=4623ded3cb580d4dae557a9002f60cab1480c75d29645ced7f8fe5b4812c0559, content: 'Deep erythema and inflammation after re-epithelialization of superficial wounds is a sign of scar fo...'),
#  Document(id=5bc09d5bddaf283020a3bf9455b4c3e1a567c9295b8bf437c1a22a8a427cfd6d, content: 'Osteoarthritis (OA) is associated with a gradual reduction in the interstitial osmotic pressure with...'),
#  Document(id=a25692a8f6694fc400cb1558058347a395dda82fad677baea54f0ed17309390d, content: 'Augmenter of liver regeneration (ALR, encoded by GFER) is a widely distributed pleiotropic protein o...'),
#  Document(id=32ebe758bc6d4df95f933f1d21056cd8fda30fb770a117f58f57e5c9357eb35d, content: 'Esophageal eosinophilia can be proton pump inhibitor (PPI) resistant or responsive, representing 2 e...'),
#  Document(id=62b86e73451608defe858241fe16dab346b309a00ca87cf29ba2367c4b139f8e, content: 'We compared the results of laboratory examinations, echocardiography, arterial stiffness, central bl...'),
#  Document(id=02a7ac993227e48d5c9a330f30e40d0966e774ecabadd7fb787c27ed93977bad, content: 'Rotenone is an environmental neurotoxin that induces accumulation of α-synuclein and degeneration of...'),
#  Document(id=e0b151a1ab878930f5d87e6e851d0419c0b81bb5b4a1adc147c5ccf033cfd2e7, content: 'Acute pancreatitis (AP) is a systemic inflammatory disease, and cytokines are suggested to be relate...'),
#  Document(id=f89d93cef5527a7055385626f814606949879cd3edb95a8dad930b7289ddd01b, content: 'Troponins may be elevated in patients with pneumonia, but associations with myocardial infarction (M...'),
#  Document(id=24cadd968c3cd2cc1d705e1360ad003aa692511d1424d6fe1b8a24182ba45959, content: 'Dipeptidyl peptidase-4 (DPP4) was recently proposed as a novel adipokine linked to insulin resistanc...'),
#  Document(id=de1eac4fdb98cc9fc568c9cdb8d7d7750aefde61172cbb9ea82d397922b8436e, content: 'To test our hypothesis that initiating therapy with a combination of agents known to improve insulin...'),
#  Document(id=4ea68a112cd1f5b4604d2e77c29b912510ab1d802901ad5b560c99fec369903a, content: 'Obesity and hemorrhagic shock following trauma are predictors of mortality but have conflicting effe...'),
#  Document(id=04b389b108b18fd22098ccf797da74099395584ff0d93019ab6201104198fdf8, content: 'Acute rejection (AR) after organ transplantation results in transplant arteriosclerosis (TA). Endoth...'),
#  Document(id=32e6b40e4afca5e695b321cb2d5fada3726ffbd487ce937f7db47181ebd8dd75, content: 'To investigate serum beta2-glycoprotein I-low-density lipoprotein (β2-GPI-LDL) and oxidized low-dens...'),
#  Document(id=36aab51af8fb1e9b67359861cf33cc84f826cf46396daaebb4989bc6429b0d8d, content: 'The blotchy mouse caused by mutations of ATP7A develops low blood copper and aortic aneurysm and rup...'),
#  Document(id=68bbda1663c36f295f93a7077d49afefc741be0fbee720303fc4911b8759d517, content: 'Animal and human studies suggest that programing of the hypothalamic-pituitary-adrenal (HPA) axis ma...'),
#  Document(id=6a6a7b2ec1fa807a1e5fd4c6059ffdb72dfe06cacb5aab5222dd642a599369b5, content: 'The optimal clinical context for initiation of salvage androgen deprivation therapy (SADT) following...'),
#  Document(id=65b7b09f0388ac45ba5c0bddae3085f7c2c295b05f9fd78d304788cffa25c62b, content: 'Hepatocellular carcinoma is one of the most common malignancies worldwide. The only curative treatme...'),
#  Document(id=8dd7b0c08d092756551c0f3d9b0c1aba47bf927c60caad1a4a4aa8802651337a, content: 'To investigate the association between early menarche (menarche age < 12 years) and Type 2 diabetes ...'),
#  Document(id=a8afb4026f1132ac0013f8811ab1066a57cdd2236d5ee6a23b48eaf5e2fc67e5, content: 'Extracorporeal membrane oxygenation (ECMO) support is often required in the management of perioperat...'),
#  Document(id=d0460ec77971a262ad53de19edc21c93ad66d166a9b66a93f91fe85c0224299a, content: 'Although early primary repair of tetralogy of Fallot has gained wider acceptance, there is some spec...'),
#  Document(id=e9c759e9fe7a3862b7e9964661ca0b92155e54b99510c68b11920cdf73fbc413, content: 'The Royal College of Physicians (RCPL) National Early Warning Score (NEWS) escalates care to a docto...'),
#  Document(id=1a5b15d6b83f512841eba79132ceecbd30df226b9e372fb977fdd8cca60862fa, content: 'Much evidence suggests that plant communities on infertile soils are relatively insensitive to incre...'),
#  Document(id=a2af5e51a76918a1dea2c2271ec6637d903ac856735878612c67c60c49a3b1ce, content: 'Esophageal carcinoma is one of the most aggressive human cancers, and novel treatment modality is re...'),
#  Document(id=9b6c00ac30f10a89e526936bbd78b7c98ee4550d34ac311e73b8da8b07465e25, content: 'Lymph node metastasis is one of the most important prognostic factors in patients with esophageal sq...'),
#  Document(id=c5d59d125c16c75ca89cb6cee78c689d9adbafb5bdc62ffbc10d91758091ca5b, content: 'Therapeutic cancer vaccines aim to boost the natural immunity against transformed cancer cells, and ...'),
#  Document(id=79299ff10dd681927ca178a8d7ec4ed20871b6ae17802069a1566acb90a87624, content: 'For patients with cystic fibrosis (CF) Pseudomonas aeruginosa infection is a major contributor to pr...'),
#  Document(id=1c0596c09467c2bb2f946ab794b3818360e9865d51409693b8c4d981281d4e90, content: 'BACKGROUND/AIMs: Pleiotrophin (PTN) have been demonstrated to play an important role in the developm...'),
#  Document(id=0701ef0747e22f4c1a6b204bc2844937ed7adbe25d8c6cab2696ea389e608e97, content: 'The cyclooxygenase-2 (cox-2) pathway is now recognized to be important in human cancer development a...'),
#  Document(id=235aec5c158b8c6cf1f7de92ac4ba79202d65e8d9c72baf4ed3da6402f9de667, content: 'To test whether subsensory vibratory noise applied to the sole of the foot using a novel piezoelectr...'),
#  Document(id=fa7d8d0c38031ae58e7271278c44b21e90b3897f80a29bc690af9c4d10cae954, content: 'The role of sleep in the enhancement of motor skills has been studied extensively in adults. We aime...'),
#  Document(id=4db07532f460927efd517fd51c1dfd52193a08febb3c4bcc70817407e6fb8040, content: 'Cenicriviroc is a potent antagonist of the chemokine coreceptors 5 and 2 (CCR5/CCR2) and blocks HIV-...'),
#  Document(id=3148f90eab088ddde12fd6040e006beb50d6ca352f1998b1b92ddccb73027444, content: 'Cicatricial alopecia is a form of hair loss that causes both cosmetic and psychological concerns. Al...'),
#  Document(id=90dad2dd06c71451089686a1db2542569dad6eac2aa0bdb7a4c4b4829ee52c67, content: 'The aim of this study was to review the impact of salvage external beam radiotherapy (EBRT) of postp...'),
#  Document(id=1dfa09427355e4fca218f324cbd60e5567f9b1e4b3afe355adc1940f931108fc, content: 'Hip dislocation in children with cerebral palsy (CP) is a common and severe problem. The Swedish fol...'),
#  Document(id=c750b26a446e86f41fd3c1d73c407506f19dba55840eeb6953233cdc2c8ef4b5, content: 'Our trauma service recently transitioned from a pulmonary intensive care unit (ICU) service to a sur...'),
#  Document(id=f059d6c9d6510a919a7fade6de6489db5c98aebeb0d980b1a20c57ddd14cd114, content: 'Avoidant personality disorder is characterized by pervasive anxiety, fear of criticism, disapproval,...'),
#  Document(id=ffaddc0537101ece17ab38023ab66579596f9e3cf326bb5171df1555b1a97717, content: 'Studies have reported effects of prenatal marijuana exposure (PME) on cognitive and behavioral outco...'),
#  Document(id=a7fe1118b1bad13e44e30686359e159aa752f17621bca4dbeb40c77ef52a67d9, content: 'Nuclear apoptosis-inducing factor 1 (NAIF1) could induce apoptosis in gastric cancer cells. Previous...'),
#  Document(id=23cf563323a6cb50d7892184fe56db952de3acc40d594bfbfc4336fb7ad6df93, content: 'Interferon gamma release assays (IGRAs) are widely used to detect pathogen specific cellular immunit...'),
#  Document(id=ee657cd3935acaa09ab6d5f36bc808c3c2735e6f9fc69c2ff8358de7c9efc162, content: 'Although excess alcohol consumption has been believed to cause liver injury, light alcohol consumpti...'),
#  Document(id=5d7100ce6b4add6cb78709606659704c37238b189e7767ac2ffbe06e22f357f0, content: 'Genomic selection (GS) may improve selection response over conventional pedigree-based selection if ...'),
#  Document(id=29748000ec004263d50052d8df9bdebd666229ac93dc2f7ec4f18a8a82b4bf80, content: 'There is great variability for the type of anaesthesia used during TAVI, with no clear consensus com...'),
#  Document(id=405f651b713fa3400ebcd4580fe5df22bc31b02e052be26fe0c22f7abdc1729e, content: 'Multidrug resistant (MDR) uropathogens are increasing in prevalence and may contribute to significan...'),
#  Document(id=61178545a9566699dccb167ed9fe21010eb994134f983d3d076e23244db520b8, content: 'Fibrinogen is a coagulation/inflammatory biomarker strongly associated with atherogenesis. However, ...'),
#  Document(id=a3af42111dedf94d79cadd5cc373508a506e93f6b0aeddaa1b04d338eaa1b3f1, content: 'Suboptimal adherence to antiretroviral therapy (ART) is a strong predictor of virologic failure (VF)...'),
#  Document(id=4d95fc3abeeccbaf4b3411afba26db81e1070967a8e3a93e99ee11a4d37703f6, content: 'Allergic asthma is characterized by inflammation and airway remodeling. Bronchial epithelium is cons...'),
#  Document(id=21e750e58bc943b185881b37ce55c2679707499ac3e2729f2763f27c6f11608f, content: 'Many peripheral biomarkers, including low cholesterol and its fractions, have been examined to ident...'),
#  Document(id=6a1c2ab25070354175903c4ec7e5715efb09c3d3ccac0a1676c377112fbf5374, content: 'Research evidence supports a positive link between soft drinks and depressive symptoms. However, dat...'),
#  Document(id=9a63ea8d45f8541108b849e1cdbdf25681b1c3b34b6330b9b198672a7382b5dc, content: 'Acute alcohol intoxication has been found to increase perseverative errors on the Wisconsin Card Sor...'),
#  Document(id=a28f8c436f237c9fb517593a81849b7525230e4d086bc495a09cc52052ab4982, content: 'The role of sexual activity on gastroesophageal reflux disease (GERD) is an under-recognized concern...'),
#  Document(id=f7fe22c7847127ad15452d6e745c7d07cf522488a43c523e2df2fb18ea56019e, content: 'Trauma is the leading cause of injury and death for individuals aged 1-44 years. Up to 8% of the US ...'),
#  Document(id=38c72f26bfd055520086d1c872bb7bd6d1285a9c82f27b0adfc34b48ab8ec9ca, content: 'Exhaled nitric oxide (FeNO) is a biomarker for eosinophilic inflammation in the airways and for resp...'),
#  Document(id=9e54bde039e0c6a3960b771fa6ee1772110690a09d090da7b868122f98bde7b9, content: 'Menopausal reduction in estrogen causes increased adipose accumulation, leading many to turn to diet...'),
#  Document(id=fe25a6a8724c66aa50beadf98b0ae141f28789211cd8832a381f20962919ac84, content: 'The purpose of this study was to investigate the clinical value of real-time three-dimensional trans...'),
#  Document(id=0f0087151ba4b1c2b73d2262bd84bb8f8cb7aff9c78c2559921ef9de2dedf8cf, content: 'Child maltreatment is associated with dysregulation of stress-mediating systems and an increased ris...'),
#  Document(id=7531e8fafa54bf01e468bd2f456b8d2687932522115b6af678798825fc978f90, content: 'The relationship between self-reported lifetime traumatic brain injury (TBI) and drug and alcohol us...'),
#  Document(id=298e90221b79deb5a068a06b63414fb790cef115e6755b8c895b01c0193ec8d7, content: 'Although epidermal growth factor receptor-tyrosine kinase inhibitors (EGFR-TKIs) have become key the...'),
#  Document(id=76d3555cf1a91c99301928018366837a379fe93988a8ab8079b1b020595165d1, content: 'Increasing evidence suggests an association between diabetes and risk of venous thromboembolism (VTE...'),
#  Document(id=043478d6fb6164fb134bc550998a46c34604f09d9ad1de1e97e87de5f87e5b53, content: 'Local invasion is a common pattern of spread in uterine cervical squamous cell carcinoma (CSCC). Alt...'),
#  Document(id=8041fe148543d18931ce79a102d82f2c0e0397eb7e170ab03dafcbdd12bd5367, content: 'To determine whether cancer antigen-125 (CA-125) levels are increased in women with endometriosis, e...'),
#  Document(id=1ecbf537fc9d36f2fb475ba71edbb756c70087fdadb638fe4a5fefbae7b77657, content: 'We examined the phenotype and function of lymphocytes collected from the peripheral blood (PBL) and ...'),
#  Document(id=c07b0019044095c74ec9632e0cb08a3bb3a7960a2fc75c0c66d7c68c713343ee, content: 'Retrospective evaluation of the long-term health-related quality of life (HRQoL) among survivors aft...'),
#  Document(id=9a11d13bf49bc55a95ab3610099dcf6d7f22a81219345f220e677e7d1db36c35, content: 'The aim of this study was to evaluate the effects of maternal obesity on pancreas structure and carb...'),
#  Document(id=9ab2e2c2a23122d8bc14851973bdb825616960cecdd0041d6208daf653b3cd22, content: 'In a recent clinical trial, patients with newly diagnosed glioblastoma multiforme benefited from chl...'),
#  Document(id=e748cdf2abb1776560fc78792fa0e8586fb037c9770580b25e9d22dc8a203ecf, content: 'The objective of this study was to report the authors' experience with the long-term administration ...'),
#  Document(id=4ebbb414658ec29708aa455c321ba7dae5c6efd0dc20173431b5832162faa69a, content: 'Hyponatraemia is a common, potentially life-threatening, complication of thiazide diuretics. The mec...'),
#  Document(id=707b9665a46b757ca67ef115ec34ba2e65360145fd09855013a944932f9b2afc, content: 'Achievement of early therapeutic anticoagulation with unfractionated heparin (UFH) is associated wit...'),
#  Document(id=2c3dda243dd9e143adf473366763f2ab285c16c1c8b3fe6722da5067268d16ec, content: 'The International Atomic Energy Agency sponsored a large, multinational, prospective study to furthe...'),
#  Document(id=10af776d91eb74038753053909c25de70a13d0ff0a409c906d1c1b842d67dd62, content: 'Myriocin is a fungal metabolite with antiviral activity, including influenza, hepatitis B, and hepat...'),
#  Document(id=2842ce0649f6e95c0b953134d43d03bbb283fc79ed594e752c57bb15186aae02, content: 'Previous investigations by our group have shown that prenatal treatment with lipopolysaccharide (LPS...'),
#  Document(id=5494598f1492962b26f673021e4e6a0924d0c6e75ed468f1de1b25ea8ef4d8bc, content: 'Alterations in epigenetic processes are frequently noted in human disease. These epigenetic processe...'),
#  Document(id=fdc52c2a78148ec8ed1f287557c13109b4d47bd6510a9551ef97b0ab784c2583, content: 'Despite recent advances in prostate cancer diagnostics and therapeutics, the overall survival rate s...'),
#  Document(id=000e8e2cba6a782e7395af5aae48a9ca62b507727d4048af257033843260e900, content: 'Strychnos spinosa Lam. is a deciduous tree used in traditional medicine to treat infectious diseases...'),
#  Document(id=93e5f64b8af95d4875cfc8f527e003d95e6cdf2e118cd447fa76ec8c639cf2f3, content: 'Sickness during pregnancy is associated with an increased risk of offspring neurodevelopmental disor...'),
#  Document(id=122af14c5c3cd32bef3563fa49a2e52afdd529808fdd8fbbf3bbe7d22a685015, content: 'Atractylodes macrocephala Koidz (AMK), a valuable traditional Chinese herbal medicine, has been wide...'),
#  Document(id=2177fdc2536b467f848460a86d091421299a4aa7a9c688c4b0d93ab3af9d1e07, content: 'Regular physical activity is an effective non-pharmacological therapy for prevention and control of ...'),
#  Document(id=89b36c21ebe9b1f8a39763c90817f0f414d4866de8048dad61582ffd74c79cd8, content: 'The chemokine receptor CXCR3 is implicated in a variety of clinically important diseases, notably rh...'),
#  Document(id=96b51db487d56a6fdab189429eb9b73abe72b2667d83630540768ad75dc0a496, content: 'Prolonged P wave duration is a marker of delayed inter-atrial conduction which may predict cardiovas...'),
#  Document(id=67ae6e023ac4d901ddd5d5299595de83ec2b009cb9cc711b2b1ee112ef3aa0c8, content: 'The present study aimed to investigate the intraplantar (ipl) and central (icv) effects of neuropept...'),
#  Document(id=264c6172435274a9f92088abef364129dfce2e206dc3e6f43a5fa371b9fd946f, content: 'Diabetes mellitus (DM) is frequently associated with peripheral and central complications and has re...'),
#  Document(id=93317d04bd4c5d06a0185cb3eab405c24fd69c2aef3d1a89104d4dcae69cea97, content: 'Gastrointestinal dysfunction is one of the major complications of diabetes. The roles of inflammatio...'),
#  Document(id=2d18a99a1c5edb35f171f47a0bc5d7a9842d96c9bdbf164b137355f5239659fc, content: 'Matrix metalloproteinase-11 (MMP-11) is reported to be overexpressed in several cancers and may cont...'),
#  Document(id=bbc715f221445fb76e5e7c836ab566069032dc1674e6a8c8a8c5d2715a1d4ad8, content: 'Interferon Lambda-3 (IFN-λ3) gene polymorphism is associated with spontaneous clearance of hepatitis...'),
#  Document(id=268ff64a8b5682a1080c53a6123872164279e05a330a89f1efdd1eccd31d0aba, content: 'Excessive anticipatory reactions to potential future adversity are observed across a range of anxiet...'),
#  Document(id=417effabbad3f1a2d9130ed2ebe9766ff0bd28cebf487a4c28dd475dd8c4d187, content: 'To compare the efficacy of intensity-modulated radiotherapy, three-dimensional conformal radiotherap...'),
#  Document(id=36cc01e024290e82d226e3591469b9780c55e207903cfd6aaf4b4293f5116ce7, content: 'Patients infected with influenza A(H7N9) virus present with acute lung injury (ALI) that is due to s...'),
#  Document(id=533628ac50212941344d8bd00ac08234e742623bb74976b6addc8b343f377687, content: 'Vaccines are very important to reduce morbidity and mortality by preventable infectious diseases, es...'),
#  Document(id=f8a70a2bfe29063c5fde5ff6ea0340298f9ddfdbc9ba729326f448c59bd029cf, content: 'Mental fatigue can negatively impact on submaximal endurance exercise and has been attributed to cha...'),
#  Document(id=079015a316cb6dd21782e52964c3a11672f39aa13dc14386292353b26ddb1fdf, content: 'The tumor suppressor p53 is known to be inactivated frequently in various cancers. In addition, germ...'),
#  Document(id=34b0da8ff26514feea85e01e934b85fb357b8411add0e76812cd1777a401fa72, content: 'α-Enolase is a glycolytic enzyme with "second jobs" beyond its catalytic activity. However, its poss...'),
#  Document(id=0bac0eed8bcb7e2c8e35e43ac5932f00dfd08735326528e809b33bad75db24bd, content: 'Most burns happen in low- and middle-income countries. In India, deaths related to burns are more co...'),
#  Document(id=2879936b9e3f09680a5c066ca48d0c811774a5a3f2bf482e67c2e499c54581eb, content: 'The purpose of the study was to determine whether racial differences exist in the pattern of local d...'),
#  Document(id=28488a623aac10a2499f9fccd802e8893e14da2147df96c3cd897e1783ae1de3, content: 'Recently, a considerable amount of evidence suggested that anxiety, depression and other psychosocia...'),
#  Document(id=1bdc1a4666b21b121b61087630a6d86dc62d31cadbfac3de1a8076cc5660582d, content: 'Sublethal doses of photon irradiation (IR) are suspected to increase tumor cell migration and suppor...'),
#  Document(id=98a18672952a141f0a1bb1ccdea003b870d80b2d19b17149b63278ce0af25199, content: 'Early-life stress and a genetic predisposition to display an anxiety- and depressive-like phenotype ...'),
#  Document(id=18fde30efc8ecaf77ead78a94d041e8418c040fdc5c35221e3a5ac03b198fd33, content: 'Some studies done in Asian patients have shown that serum levels of hepatitis B virus (HBV) DNA pred...'),
#  Document(id=a21d548f9200f85803987d1fa971688f91b716028e6cd3d7a2dc910280881a1f, content: 'The members of the patatin-related phospholipase subfamily III (pPLAIIIs) have been implicated in th...'),
#  Document(id=438fbee5f1e5c191e8c73ebdeeee3012f57fd7e0080b5f63063df21397af426f, content: 'To examine the accuracy of HistoScanning (HS) in detecting seminal vesicle (SV) invasion (SVI) withi...'),
#  Document(id=03e9e638dd72075a1fb86c43b4c2f49515b9c6b475e210fec8f3b98602d22a00, content: 'To investigate the effect of the percentage of free prostate-specific antigen (%fPSA) on future pros...'),
#  Document(id=d5709c16901d621eba225ab7f31e1ef79a1f1fa0270b343aae14064e347d791f, content: 'Right ventricular pacing (RVP) has been associated with heart failure and increased mortality. His-b...'),
#  Document(id=8c88603645963c038b8a6b50e494f27b3c3c94aa3501187e7e130e151bab8d0c, content: 'Implantable cardioverter-defibrillator (ICD) implantation is contraindicated in those with <1-year l...'),
#  Document(id=eadcd1efca9b8b72805d064278b2edbb5876194b70bf7ab6ffa73067c70896a5, content: 'Non-alcoholic steatohepatitis (NASH) is a subset of non-alcoholic fatty liver disease, the most comm...'),
#  Document(id=466d5acc213ee7dbb3cbd9dc0a28ebf9099520e98b03b299a809310fc14e698a, content: 'The purpose of this study was to determine the prevalence of vitamin D deficiency in CTCL patients a...'),
#  Document(id=f3455ff45245a0f9d606f953695774a02b490e00a148064ec041cac3662a59b7, content: 'Migraine is a common comorbidity among individuals with bipolar disorder, but the underlying mechani...'),
#  Document(id=e0a632e13530a3b06ed4919f56a7d189793a68a0260dee6d9db3b2f155fba3a1, content: 'Nonalcoholic steatohepatitis (NASH) is associated with dyslipidemia and cardiovascular disease (CVD)...'),
#  Document(id=e488ac79ba8e887830922ac2b85d7f47a7bd881ef30297c5a52117fa84387ddb, content: 'Cadherins are calcium-dependent cell-to-cell adhesion glycoproteins playing a critical role in the f...'),
#  Document(id=527e11e9f62ed63e3fb439a70bb0fd29400de0a1e381adff73cac283458d0da1, content: 'The fruits of Vitex rotundifolia L. are widely used to treat inflammation of the airway in Tradition...'),
#  Document(id=e85ea4aefb4840409d157f9a118ea7eb95e020ad9b8d4bbcf242d2ac069f1cef, content: 'The rubber tree, Hevea brasiliensis, is a major commercial source of natural rubber. Increasing the ...'),
#  Document(id=5b3aedf720f7b37fae441d893e13fec42890886c3d9623e85616bb5887a8a14c, content: 'Growing evidence shows cannabidiol (CBD) modulates some of the effects of Δ(9) -tetrahydrocannabinol...'),
#  Document(id=ad5e8e13db3e908f961c5036eb2d7ca67bf7435edffc49ed68b6807c8e2a8ff6, content: 'The effective mechanisms of microRNAs (miRNAs) functions as oncogenes or tumour suppressors in human...'),
#  Document(id=fb8a2ced51fe51039d23d3f952b756c5da086ba4d0a99f6125827506556a035c, content: 'Non-small cell lung cancer (NSCLC) is one of the most common malignant tumors. Despite the advances ...'),
#  Document(id=c33e3f9f60da97b9068d3b90bd4b83af9aa749f67a486b3d5345651e93a5c459, content: 'We previously demonstrated that 6-benzylthioinosine (6-BT) could induce the differentiation of a sub...'),
#  Document(id=8dd96e2fa0e6e979346b08c6c710cea7786aec66a87a8c1bfdc3c1d68b7401a1, content: 'Ginsenoside Rg3 is one of the active ingredients isolated from Panax ginseng C.A. Meyer. Previous st...'),
#  Document(id=bc1c724e18a97d86891db17da2845e3be339a02f95e736dac71de29edff67566, content: 'Some cases with non-alcoholic fatty liver disease (NAFLD), particularly non-alcoholic steatohepatiti...'),
#  Document(id=4045a6c26bbcac9207a7dedbf57690b57172803bbf50eaf41119b1d6f17be974, content: 'Notch signaling plays an acknowledged role in bile-duct development, but its involvement in cholangi...'),
#  Document(id=e7f8fe42643c6f51611e2ca5bbd92590d38beaaebcaf1f2d51176fdd67c64cc5, content: 'By binding to T cell immunoglobulin mucin-3 (TIM-3) on activated Th1 cells, galectin-9 (Gal-9) negat...'),
#  Document(id=832d2d776bcddaaae7d2a8df258ff674a5acc7487898b0289272132cd59fd513, content: 'Preoperative suspicion of malignancy in pancreatic neuroendocrine tumours (pNETs) is mostly based on...'),
#  Document(id=e1b623d9ca8f342ff6c5407978e58a4fd15f24087a42151412e909615bebba7a, content: 'Ketamine is a widely used anesthetic in obstetric and pediatric anesthesia. In the developing brain,...'),
#  Document(id=222a0b6970dfc655632243f1aab32ec4a3190d5b7001254b0d8144b00025ea87, content: 'Wheat (Triticum aestivum L.) is an economically important grain crop. Two-dimensional gel-based appr...'),
#  Document(id=f50478dee24b4bb9e3845bf5c49950eef4b783b65618c355112efdd2bf2c86e7, content: 'Low vitamin D status (serum 25(OH)D concentration) is associated with increased incidence and unfavo...'),
#  Document(id=bdd79f434a2010b87cde20d0a10f7ea5f8e85bf385a5327e4816014f0592f053, content: 'Rural primary health centers frequently treat patients with tick bites. This study compares everyday...'),
# ...
#  Document(id=2c852e87a2364592faa98d84466062164f8dc90a807a8ea33fedf42499ca8223, content: 'The aim of this study was to analyze the biochemical and histochemical effects of radiation therapy ...'),
#  Document(id=60c4844dce469e82144cde82e90731c283141d8769d7665512405b5e03af840f, content: 'Transient receptor potential ankyrin 1 (TRPA1) is a membrane-associated cation channel, widely expre...'),
#  Document(id=1c321616230a071ed37f0b61e0956fbef47738c8cf2335329b2eee25a025b64e, content: 'Managing aggressive breast cancers with enhanced chromosomal instability (CIN) is a significant chal...'),
#  Document(id=271df370059a62d9429b5641fd42779ca66204d66f24bd212b608211caceae7f, content: 'Ovarian cancer is the most lethal gynecologic malignancy, and there is an unmet clinical need to dev...'),
#  Document(id=5dc5ede83dbe98da0223932a85fe40fad11590e6b6079d1ec7c322425c6903f9, content: 'Transport across the blood-brain barrier (BBB) is an important mediator of beta-amyloid (Aβ) accumul...'),
#  Document(id=1e7fcfbf7637907a6c691ec766e7de528bc3c035473a4aa687080b66f8d1012f, content: 'Cardiac mass and volumes are often elevated in athletes, but it is not known whether moderate physic...'),
#  Document(id=2eeaf08cac74ac847fcd4fb9235ba8ec28f4215cbc254c0fb37c61dc2edc19e4, content: 'Cardiovascular magnetic resonance T1 mapping characteristics are elevated in adult cancer survivors;...'),
#  Document(id=1c09944941f1d9285e534f0ec32f0fb845e2fefbdbf2eea1608d05a63867166a, content: 'It is controversial whether high salt intake is directly associated with cardiovascular (CV) events ...'),
#  Document(id=36748ea7cafe5907f86e118d509be1f2777e724e0869da9a1b18455db9772b20, content: 'Prior work shows that palliative homecare services reduce the subsequent need for hospitalizations a...'),
#  Document(id=7a948c9b1757d3ff81ae2950eccabcc5ec58bbd542c367fe32fc8b3240695696, content: 'To clarify the lowering effect of metabolic syndrome (MetS) on serum prostate-specific antigen (PSA)...'),
#  Document(id=ffdb5de73a0e5c1f3b53f7623cdd1a58687387582e22344639f1354c4b03ba1b, content: 'Increasing evidence points to the inflammatory character of atherosclerosis and several parameters o...'),
#  Document(id=0ec5e45152a8a0277d58f316cc034b8acb7672ed09c8173b22aabe48e360d15d, content: 'B-type natriuretic peptide (BNP)-natriuretic peptide receptor A (NPR-A) receptor signalling inhibits...'),
#  Document(id=e655fc767a654e4c2b14db83b180216b7057d20e52eabca88bd9a97d13a0640b, content: 'For the majority of congenital heart diseases (CHDs), the full complexity of the causative molecular...'),
#  Document(id=cdcb00bbeb1144766b148a1d7724bf3447184051560053bf4dda05632170d9e1, content: 'The striated muscle costamere, a multiprotein complex at the boundary between the sarcomere and the ...'),
#  Document(id=3ce11dffff3a9b0d932fb0bb6f482d99037baafb3d52590507ae6b29d3d892e5, content: 'Substantial country differences in neurosurgical training throughout Europe have recently been descr...'),
#  Document(id=3eefc5ab029ad66d5c0a07d0f4565cec6108ca70595b4aab4cc91e1d076eb6b5, content: 'Current diagnostic tests for gastroesophageal reflux disease (GERD) do not consistently measure chro...'),
#  Document(id=0df1e8b08da740b68708eccd4c2420bff6c245d2b92f12662bc1b2ba6f450765, content: 'The antileukemic drug asparaginase, a key component in the treatment of acute lymphoblastic leukemia...'),
#  Document(id=332157ebad41cbcd666558d24093cafb7711010c9e9da158d31936d303e6dc0e, content: 'Enterococcus faecalis is a pathogenic gram-positive bacterium closely associated with apical periodo...'),
#  Document(id=081a0959764b3bfe4eddc1864eb5e7134ba3a3d15a3d7e8e5c2097562f3f645f, content: 'Substance use and crime/recidivism are irrevocably linked. We explore the nuances of this associatio...'),
#  Document(id=fcbeefe4f5b9ae47c62d0057fa62a87fe2d772452fa5e73cc208dbfc9ccfa42c, content: 'The relationship between post-exercise heart-rate recovery (HRR) and resting cardiac autonomic modul...'),
#  Document(id=907656a221671100510c14397f9f62cd561ce9cbadcf842355a2e40efe4878d6, content: 'Nitric oxide (NO) is an important vascular signalling molecule. NO is synthesised endogenously by en...'),
#  Document(id=c948c0a3d54ed464380149e4698e32a9f9de9192e4c0b1f014a110207213d9f3, content: 'Bacterium-to-host signalling during infection is a complex process involving proteins, lipids and ot...'),
#  Document(id=4b4ab4b945a0a80634fe48aa107e16be1201b4273ea94e2ad3bc8fc7c6e23844, content: 'The age gap between participants in trials and patients who could benefit from the drugs studied has...'),
#  Document(id=97187b36ecfcb53d428d8f991d6b4c4a92239fc7294325fd02114ac7a6e7375e, content: 'Hearing aids are prescribed to alleviate loss of audibility. It has been reported that about 31% of ...'),
#  Document(id=f7f0083ff6b699c2de33d79f7b7dda709e51bbc21485df2098d2a8e10e26b2bb, content: 'To determine the association of statin use with oncological outcomes and risk of pathologic upgradin...'),
#  Document(id=952e641d7380b74d564bcc3744cfd037bb1534b7a0524e66fbff588b84975fbf, content: 'It is known that large dogs who are fed lamb and rice diets are at increased risk to develop taurine...'),
#  Document(id=859361a8c4c927e6250558da5507c93a13ebacb0761ef6747b3ee65bbe67ef27, content: 'Familial hypercholesterolemia (FH) is a genetic disorder characterized by elevated levels of total c...'),
#  Document(id=cfd424a2c4ba814417d753af7f58b4fbb4f949f7b5a90d794f4189a2bce8d960, content: 'Affinity purification followed by mass spectrometry (AP/MS) is a widely used approach to identify pr...'),
#  Document(id=4a6cc9d788894e13b5388f910352a2012d249d7e31bb9c907a4397451eeaa74d, content: 'A recurrent finding of trials on renal sympathetic denervation is a certain percentage of non-respon...'),
#  Document(id=1b6aefc368dd91885bf46bdcec876c4f15148b11daf28995fa6cf58acab7ebd8, content: 'Metastasis is a primary cause of colorectal cancer (CRC)-related death, and cancer stem cells (CSCs)...'),
#  Document(id=b900bcbe0010f885c2e0cf94ada1900abb1e20e269ff7f60a7a7b661326df81e, content: 'To define the predictive capability of serum C-reactive protein for a contemporary patient collectiv...'),
#  Document(id=bde60f4398b0b87ebfd8df04a1c00265da9d96af1164dd1e375d3c4cea8f9915, content: 'Young children with sickle cell disease (SCD) are at risk for cognitive delay. In addition to biolog...'),
#  Document(id=f975f63ab6e3d59dc54b28c0b8a110d713873e8a3055952447f0edf2a82efe96, content: 'To determine the rate of persistent tracheocutaneous fistula (TCF) in pediatric patients managed wit...'),
#  Document(id=17c43e21ec3d7ffa7da9c6db7c290e8f6e2713164f00f74b8763aae64daec71d, content: 'Areas of high signal intensity (HighT2) on T2-weighted cardiovascular magnetic resonance (CMR) imagi...'),
#  Document(id=b032252aac0a382a81cbd057b68c5022813033496a607d54d23e00c7186a8c9f, content: 'Comparison of the efficacy of tropicamide eyedrops to the combination of 0.5% tropicamide and 5% phe...'),
#  Document(id=2e7dbafa8d3e27b6adcc6266d8b8b3a66ba0684a227d851ce95cc6f8dc67a482, content: 'Our objective was to identify the antioxidant properties of honeybee products from Turkey, chestnut ...'),
#  Document(id=5f1a838cfc99654770d62abf1e60d994d1ba05b9b85055028663eda0511e7566, content: 'In order to determine the synergistic effects of human placental mesenchymal stem cells (PMSCs) on h...'),
#  Document(id=dafa8281190c0073eb7db72a53af2bea5f12973a7b149e220ad75389cdcd3de7, content: 'The chronic inflammation plays an important role in heart failure and complement components might be...'),
#  Document(id=9c47cd9ea243be366db559a7d70d9c122bd8daa808ae661427ea98745cfb5901, content: 'Accumulating evidences indicated that lncRNAs play crucial regulatory roles in oncogenesis and progr...'),
#  Document(id=2c3fceae540b17717c8317083de7db2092803e5fc7e137dc0a7d02827e5d1257, content: 'In the context of advanced immunosuppression, M. tuberculosis is known to cause detectable mycobacte...'),
#  Document(id=6e8a71c79fdd90860729e4d079ba942d182d41e5807889d86e04fd7b53735029, content: 'Previously, using imaging mass spectrometry (IMS), we discovered proteomic differences between Spitz...'),
#  Document(id=c0a157ec7657fbb1c285675f82b4076490493f1eaebb7c1890a080346fb94f6a, content: 'Declines in skeletal muscle structure and function are found in various clinical populations, but th...'),
#  Document(id=f894919ecac83229dc900b3e2d8b5603de9717228ee3d9b6650829e7b6da76da, content: 'We investigated the pathway of autophagy signaling linked to sarcopenia of mice. Young adult (3-mont...'),
#  Document(id=8152805ecc83b6ff5b41bb287e3d380ae5e6a2e7276f4207c433881ca6bbaf33, content: 'Cachexia has a devastating impact on survival and quality of life for many cancer patients and contr...'),
#  Document(id=dac4bd6be5f6d7ca3ab8713e71beaea64d0d35f6319828530d6f137cad6a6dca, content: 'Calcitonin gene-related peptide (CGRP) is thought be involved in the modulation of intestinal motili...'),
#  Document(id=33cb24d93651d981256818197f508b49c21ece2d2dd632a90f10c30ec567a6f3, content: 'In this study, we compared the success of sinus lifting and alternative treatment methods in applyin...'),
#  Document(id=9314d3c2a3d34a0aeaf74171177b343d17da839822f1caf1405ce18a7e0e78f5, content: 'Lipopolysaccharide (LPS)-induced preconditioning protects neurons against traumatic spinal cord inju...'),
#  Document(id=e8a066cffd6bb955418e783ddce1f8c77e322baa759876f2a026c8be8fe9f33a, content: 'The receptor for activated protein kinase C (RACK1) is a scaffold protein involved in multiple intra...'),
#  Document(id=dd81cf8e23baca5d772bfa5ae18ad5710b7311ea90cc245c020fef8bf27e98e5, content: 'Glioblastoma (GBM) tumors exhibit strong phenotypic differences that can be quantified using magneti...'),
#  Document(id=86c072c8222a1c1beff174f5f0fc9a050a4ad77af79eeac8d89ae26bbf59d359, content: 'Transfusion of packed erythrocytes stored for a long duration is associated with increased pulmonary...'),
#  Document(id=c472be25e67881c6fbaef403bf4e56a60bfddc3bd412a51269a56befbf35c7cf, content: 'This article reports relationships between serum cytokine levels and patient-reported levels of fati...'),
#  Document(id=02f2232ece96afb2c54ea597fbca7e4e3ea26f127345f6981222b47a48d3f272, content: 'Lower respiratory tract infection is a common cause of consultation and antibiotic prescription in p...'),
#  Document(id=4605fc5f5587641352d2fb1208e09ab304a246317484600facd0e9f72ea5049a, content: 'Pectins are one of the main components of plant cell walls. They are secreted to the wall as highly ...'),
#  Document(id=1397fa57df3a3a9e17698da8185bb6b4e3bf587b5399149859127fbe89752968, content: 'Nitrofurantoin is a nitroderivative antibiotic that has bactericidal activity against pathogens caus...'),
#  Document(id=4e7326b131be5e7675c05743d48f244561ce6daff2f2ea4bd5810bc7b9899243, content: 'The isoflavone puerarin [7-hydroxy-3-(4-hydroxyphenyl)-1-benzopyran-4-one 8-(β-D-glucopyranoside)] p...'),
#  Document(id=8546eb6f88c301544ed05bec293a70a7c3bee483481597cc9219b9cde6d8e954, content: 'Plant genomes are populated by different types of repetitive elements including transposable element...'),
#  Document(id=86493ee219e9e324b76ba0f2a961c0b4a46e3bf5e0931653979392a5c9805abc, content: 'Malignant astrocytic gliomas are the most common and lethal brain malignancies due to their refracto...'),
#  Document(id=bb459abea2cc9668a68d1bd008cdb85628bad649f22b49f58276a67edd1a7140, content: 'Habitat selection may have profound evolutionary consequences, but they strongly depend on the under...'),
#  Document(id=c58d580d0db6bd3af4d31e3b270cd2d0bfdae948e86d3b3a6dd1614d95f4b640, content: 'To determine the role of NOTCH during the arterial injury response and the subsequent chronic arteri...'),
#  Document(id=f70f442ae1379aa8a29ace3c886bccaca24c1163ce1325340b78f8e28d68f591, content: 'Material loss at the taper junction of metal-on-metal total hip arthroplasties has been implicated i...'),
#  Document(id=a097aa6d4fd376ddf9589a99aa3bd728275dee994af708b9012bbfc890acee16, content: 'Although posttraumatic stress disorder (PTSD) and chronic pain frequently occur in tandem, the patho...'),
#  Document(id=a673808412e74f815ce0ab3ffbf48bcce4590c86461215b2dce7ae57c25ff879, content: 'The EuroSCORE (European System for cardiac operative risk evaluation) stratifies cardiac risk surger...'),
#  Document(id=942595b94895653360aa867c8a7a39595b4e373e440901d37e22d98f08d8808f, content: 'Cancer pain is still inadequately treated in up to 60% of cancer patients. Based on the additional e...'),
#  Document(id=d3013fa66f2777851b3c0ce6973ff0253f1a38b89a731ca73e0f0c5607b3083b, content: 'Essentials Platelet-Factor (F) VIII gene therapy is a promising treatment in hemophilia A. This stud...'),
#  Document(id=005d83dd717eb6e76862d73066a05c82c01a52a4805bbf59eeeb6755dd60b949, content: 'A high serum angiopoietin-like 2 (ANGPTL2) concentration is an independent risk factor for developin...'),
#  Document(id=4e6c262e14abcae5033402cfab4dbc37a4572c5e93e5be5e345df5d2a4b2370e, content: 'We previously identified two ARDS subphenotypes in two separate randomized controlled trials, with d...'),
#  Document(id=91d11a2c6544a612c812e76e16cf74512d9949d1494cb09795c3aab108785cf3, content: 'Genome-wide association studies have identified 200 inflammatory bowel disease (IBD) loci, but the g...'),
#  Document(id=3789e58f95254fa099f85e26baf7bd6d0cd8482509e5043ea0042d6252623318, content: 'Preoperative neutrophil-lymphocyte ratio (NLR) and platelet-lymphocyte ratio (PLR) have prognostic v...'),
#  Document(id=1a1375a5fc503a6ade7e2ae94a6404513c98873b4414bae44188b95e241f15f8, content: 'Angiotensin II (AngII), a vasoconstrictive peptide of the renin-angiotensin system (RAS), promotes h...'),
#  Document(id=1ebe79597704d63f7ce1ee78122c89ebf13849da6274d42ff64155afd817bdfa, content: 'Platelet-rich plasma (PRP) therapy has become an increasingly popular treatment for orthopaedics and...'),
#  Document(id=14d47a8a58309e418ec7efe13b494883733374593cb057967aeba43ed93e6d79, content: 'Antibiotic resistance is a challenge in long-term care facilities (LTCFs). The objective of this stu...'),
#  Document(id=63ddab7e70d66af8b7c08fd62ace732a172a7dc825c161bc83a95da5cbe60eb7, content: 'Despite modern antiretroviral therapy, HIV-associated neuropathy is one of the most prevalent, disab...'),
#  Document(id=c6e0c9b6bdba39457a1c2e452964fed66b2ecf5bc67d5f20e9dfdf2a4eda26c9, content: 'The Muscle-specific RING-finger (MuRF) protein family of E3 ubiquitin ligases is important for maint...'),
#  Document(id=7fbdd80c5d68153a207311c1eeba929d68247e55d94aaae3e748949b5c617d8e, content: 'Neural networks that regulate binge eating remain to be identified, and effective treatments for bin...'),
#  Document(id=9badec15eccf37bc00f804b11867922de91e5616621bddbd7c685b2d2a8990ae, content: 'Transannular patching (TAP) frequently accompanies primary repairs (PRs) in symptomatic neonates wit...'),
#  Document(id=fa8311c040ae944f0b45bbfb24fceefedcfa329b48c0029bf5082f12959ea23d, content: 'To determine the effect of diagnostic ureteroscopy on intravesical recurrence in patients with upper...'),
#  Document(id=4589c59d9d58726cf9d6bf7e8dec7dd9c15007f264f1ef23573ce71d415e172e, content: 'Lung adenocarcinomas with mutations in the epidermal growth factor receptor (EGFR) have unprecedente...'),
#  Document(id=6d8268955021f11643ff1de684589d21a0ea63cc2d902c21d50b670cef03f901, content: 'Excessive time between the first presentation of symptoms of pulmonary tuberculosis (PTB) and diagno...'),
#  Document(id=d53cdb21c18525f6f186b09219f1a695b7a28237cd5a556181365f02fd97405d, content: 'Invasive infections caused by KPC-producing Klebsiella pneumoniae (KPCKP) are associated with very h...'),
#  Document(id=bb6b84bf045e606dcc7ce203a41dce37416b4739d95a18e59d435ac6b59f9b6a, content: 'Diabetic cardiomyopathy (DCM) is associated with suppressed autophagy and augmented apoptosis in the...'),
#  Document(id=7e34248863170a8be30b4a2d23083121f6472658b4e988f88e50c378e4533868, content: 'To explore the effects of sulforaphane (SFN) on neuronal apoptosis in hippocampus and memory impairm...')]

# %%
from haystack.document_stores.in_memory import InMemoryDocumentStore

document_store = InMemoryDocumentStore()
document_store.write_documents(docs)
# Out:
# 1000

# %%
document_store.filter_documents()[:5]
# Out:
# [Document(id=f6fde0752a035f7a15860dfa6c45d3ee05380198f18abf43b7b4923ec44c9985, content: 'Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 inna...'),
#  Document(id=8889ef27dbfe0b3cc5ba24652b393fc9e39cd49d21db1b7dbeb8a79363b4fb12, content: 'Phosphatidylethanolamine N-methyltransferase (PEMT), a liver enriched enzyme, is responsible for app...'),
#  Document(id=699ac0bd51891960eb58709be9f2ffef41fcbc7ea51f247c7b922e3ad1e358c3, content: 'Psammaplin A (PsA) is a natural product isolated from marine sponges, which has been demonstrated to...'),
#  Document(id=8c714387bf3999ef9b3e11997d8dc5f894ee2ffc281202db4c1a66faf65e5752, content: 'This study examined links between DNA methylation and birth weight centile (BWC), and explored the i...'),
#  Document(id=7a59e616dab6b59e767513a13b3cd3551843c52d3349c1fd2a6c827b9885912c, content: 'Tumor microenvironment immunity is associated with breast cancer outcome. A high lymphocytic infiltr...')]

# %% [markdown]
# ## Initial Haystack pipeline
#
# Let's create a simple RAG Pipeline in Haystack. For more information, see [the documentation](https://docs.haystack.deepset.ai/docs/get_started).
#
# Next, we will see how to improve the prompt.

# %%
from haystack.components.retrievers.in_memory import InMemoryBM25Retriever
from haystack.components.generators import OpenAIGenerator
from haystack.components.builders import PromptBuilder
from haystack import Pipeline


retriever = InMemoryBM25Retriever(document_store, top_k=3)
generator = OpenAIGenerator(model="gpt-3.5-turbo")

template = """
Given the following information, answer the question.

Context:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

Question: {{question}}
Answer:
"""

prompt_builder = PromptBuilder(template=template)


rag_pipeline = Pipeline()
rag_pipeline.add_component("retriever", retriever)
rag_pipeline.add_component("prompt_builder", prompt_builder)
rag_pipeline.add_component("llm", generator)

rag_pipeline.connect("retriever", "prompt_builder.documents")
rag_pipeline.connect("prompt_builder", "llm")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x000002771C9B7730>
# 🚅 Components
#   - retriever: InMemoryBM25Retriever
#   - prompt_builder: PromptBuilder
#   - llm: OpenAIGenerator
# 🛤️ Connections
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)

# %% [markdown]
# Let's ask some questions...

# %%
question = "What effects does ketamine have on rat neural stem cells?"

response = rag_pipeline.run({"retriever": {"query": question}, "prompt_builder": {"question": question}})

print(response["llm"]["replies"][0])
# Out:
# Ketamine at high concentrations (200, 500, 800, and 1000μM) significantly inhibits the proliferation of rat neural
# stem cells (NSCs). It also decreases intracellular Ca(2+) concentration, suppresses the activation of protein
# kinase C-α (PKCα), and the phosphorylation of extracellular signal-regulated kinases 1/2 (ERK1/2) in NSCs.
# Additionally, a combination of subthreshold concentrations of ketamine and certain inhibitors produces
# suprathreshold effects on NSC proliferation.

# %%
response
# Out:
# {'llm': {'replies': ['Ketamine at high concentrations (200, 500, 800, and 1000μM) significantly inhibits the proliferation of rat neural stem cells (NSCs). It also decreases intracellular Ca(2+) concentration, suppresses the activation of protein kinase C-α (PKCα), and the phosphorylation of extracellular signal-regulated kinases 1/2 (ERK1/2) in NSCs. Additionally, a combination of subthreshold concentrations of ketamine and certain inhibitors produces suprathreshold effects on NSC proliferation.'],
#   'meta': [{'model': 'gpt-3.5-turbo-0125',
#     'index': 0,
#     'finish_reason': 'stop',
#     'usage': {'completion_tokens': 114,
#      'prompt_tokens': 769,
#      'total_tokens': 883}}]}}

# %%
question = "Is the anterior cingulate cortex linked to pain-induced depression?"

pipe.run(
    {
        "embedder": {"text": question},
        "prompt_builder": {"question": question},
        "llm": {"generation_kwargs": {"max_new_tokens": 350}},
    }
)
# Out:
# Yes, the anterior cingulate cortex (ACC) is linked to pain-induced depression. The information provided states that
# lesions in the ACC prevented the anxiodepressive consequences of chronic pain, and chronic activation of the ACC
# induced anxiety and depressive-like behaviors in animals. This suggests that the ACC plays a role in the affective
# aspects of chronic pain that can lead to depression.

# %% [markdown]
# The answers seems correct, but suppose that **our use case requires shorter answers**. How can we adjust the prompt to achieve this effect while maintaining correctness?

# %% [markdown]
# ## DSPy
#
# We will use DSPy to automatically improve the prompt for our goal: getting correct and short answers.
#
# We will perform several steps:
# - define a DSPy module for RAG
# - create training and dev sets
# - define a metric
# - evaluate the unoptimized RAG module
# - optimize the module
# - evaluate the optimized RAG
#
# Broadly speaking, these steps follow those listed in the [DSPy guide](https://dspy-docs.vercel.app/docs/building-blocks/solving_your_task).

# %%
import dspy
from dspy.primitives.prediction import Prediction


lm = dspy.OpenAI(model='gpt-3.5-turbo')
dspy.settings.configure(lm=lm)

# %% [markdown]
# ### DSPy Signature
#
# The RAG module involves two main tasks (smaller modules): retrieval and generation.
#
# For generation, we need to define a signature: a declarative specification of input/output behavior of a DSPy module.
# In particular, the generation module receives the `context` and a `question` as input and returns an `answer`.
#
# In DSPy, the docstring and the field description are used to create the prompt.

# %%
class GenerateAnswer(dspy.Signature):
    """Answer questions with short factoid answers."""

    context = dspy.InputField(desc="may contain relevant facts")
    question = dspy.InputField()
    answer = dspy.OutputField(desc="short and precise answer")

# %% [markdown]
# ### DSPy RAG module
#
# - the `__init__` method can be used to declare sub-modules.
# - the logic of the module is contained in the `forward` method.
# ---
# - `ChainOfThought` module encourages Language Model reasoning with a specific prompt ("Let's think step by step") and examples. [Paper](https://arxiv.org/abs/2201.11903)
# - we want to reuse our Haystack retriever and the already indexed data, so we also define a `retrieve` method.

# %%
class RAG(dspy.Module):
    def __init__(self):
        super().__init__()
        self.generate_answer = dspy.ChainOfThought(GenerateAnswer)

    # this makes it possible to use the Haystack retriever
    def retrieve(self, question):
        results = retriever.run(query=question)
        passages = [res.content for res in results['documents']]
        return Prediction(passages=passages)

    def forward(self, question):
        context = self.retrieve(question).passages
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

# %% [markdown]
# ### Create training and dev sets
#
# In general, to use DSPy for prompt optimization, you have to prepare some examples for your task (or use a similar dataset).
#
# The training set is used for optimization, while the dev set is used for evaluation.
#
# We create them using respectively 20 and 50 examples (question and answer) from our original labeled PubMed dataset.

# %%
dataset
# Out:
# Dataset({
#     features: ['instruction', 'context', 'response', 'category'],
#     num_rows: 1000
# })

# %%
print(dspy.Example(question = dataset["instruction"][0], answer=dataset["response"][0]).with_inputs('question'))
# Out:
# Example({'question': 'Are group 2 innate lymphoid cells ( ILC2s ) increased in chronic rhinosinusitis with nasal
# polyps or eosinophilia?', 'answer': 'As ILC2s are elevated in patients with CRSwNP, they may drive nasal polyp
# formation in CRS. ILC2s are also linked with high tissue and blood eosinophilia and have a potential role in the
# activation and survival of eosinophils during the Th2 immune response. The association of innate lymphoid cells in
# CRS provides insights into its pathogenesis.'}) (input_keys={'question'})

# %%
question_lis = ["Revelator supports distribution to FIZY",]
trainset, devset=[],[]

for i,ex in enumerate(dataset):
  example = dspy.Example(question = ex["instruction"], answer=ex["response"]).with_inputs('question')

  if i<20:
    trainset.append(example)
  elif i<70:
    devset.append(example)
  else:
    break

# %%
len(trainset),len(devset)
# Out:
# (20, 50)

# %% [markdown]
# ### Define a metric
#
# Defining a metric is a crucial step for evaluating and optimizing our prompt.
#
# As we show in this example, metrics can be defined in a very customized way.
#
# In our case, we want to focus on two aspects: correctness and brevity of the answers.
# - for correctness, we use semantic similarity between the predicted answer and the ground truth answer ([Haystack SASEvaluator](https://docs.haystack.deepset.ai/docs/sasevaluator)). SAS score varies between 0 and 1.
# - to encourage short answers, we add a penalty for long answers based on a simple mathematical formulation. The penalty varies between 0 (for answers of 20 words or less) and 0.5 (for answers of 40 words or more).

# %%
from haystack.components.evaluators import SASEvaluator
sas_evaluator = SASEvaluator()
sas_evaluator.warm_up()

def mixed_metric(example, pred, trace=None):
    semantic_similarity = sas_evaluator.run(ground_truth_answers=[example.answer], predicted_answers=[pred.answer])["score"]

    n_words=len(pred.answer.split())
    long_answer_penalty=0
    if 20<n_words<40:
      long_answer_penalty = 0.025 * (n_words - 20)
    elif n_words>=40:
      long_answer_penalty = 0.5

    return semantic_similarity - long_answer_penalty
# Out:
# c:\Users\sri.karan\.conda\envs\rag\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# c:\Users\sri.karan\.conda\envs\rag\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sri.karan\.cache\huggingface\hub\models--sentence-transformers--paraphrase-multilingual-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Evaluate unoptimized RAG module
#
# Let's first check how the unoptimized RAG module performs on the dev set.
# Then we will optimize it.

# %%
uncompiled_rag = RAG()

# %%
len(devset),devset
# Out:
# (50,
#  [Example({'question': 'Is increased time from neoadjuvant chemoradiation to surgery associated with higher pathologic complete response rates in esophageal cancer?', 'answer': 'A longer interval between completion of neoadjuvant chemoradiation and surgery was associated with higher pathologic complete response rates without an impact on surgical morbidity.'}) (input_keys={'question'}),
#   Example({'question': 'Is epileptic focus localization based on resting state interictal MEG recordings feasible irrespective of the presence or absence of spikes?', 'answer': 'Our preliminary results suggest that accurate localization of the epileptogenic focus may be accomplished using noninvasive spontaneous "resting-state" recordings of relatively brief duration and without the need to capture definite interictal and/or ictal abnormalities.'}) (input_keys={'question'}),
#   Example({'question': 'Does seminal Helicobacter pylori treatment improve sperm motility in infertile asthenozoospermic men?', 'answer': 'H pylori treatment significantly improves sperm motility in infertile asthenozoospermic men with elevated seminal H pylori IgA.'}) (input_keys={'question'}),
#   Example({'question': 'Does a migrating ciliary gate compartmentalize the site of axoneme assembly in Drosophila spermatids?', 'answer': 'Our findings demonstrate that the ciliary gate can migrate away from the base of the cilium, thereby functioning independently of the centriole and of a static interaction with the axoneme to compartmentalize the site of axoneme assembly.'}) (input_keys={'question'}),
#   Example({'question': 'Is individual Public Transportation Accessibility Positively Associated with Self-Reported Active Commuting?', 'answer': 'This study extends the knowledge about the driving forces of using public transportation for commuting by examining the individual public transportation accessibility. Findings suggest that transportation accessibility supports active commuting and planning of improved public transit accessibility has thus a potential of providing health benefits to commuters.'}) (input_keys={'question'}),
#   Example({'question': 'Is congenital penile pathology associated with abnormal development of the dartos muscle : a prospective study of primary penile surgery at a tertiary referral center?', 'answer': 'Congenital penile pathology (hypospadias, buried penis) is associated with structural anomalies in dartos tissue. Further research is needed to unveil the pathophysiology of the condition.'}) (input_keys={'question'}),
#   Example({'question': 'Is δNp63 expression a protective factor of progression in clinical high grade T1 bladder cancer?', 'answer': 'ΔNp63 expression is a favorable prognostic factor in clinically high grade T1 bladder cancer. This marker identifies patients at low risk for progression who could benefit from conservative therapy with transurethral bladder tumor resection and bacillus Calmette-Guérin, avoiding over treatment with immediate radical cystectomy.'}) (input_keys={'question'}),
#   Example({'question': 'Do high levels of procalcitonin in the early phase after pediatric liver transplantation indicate poor postoperative outcome?', 'answer': 'High levels of PCT after pLTx are an early indicator of poor postoperative outcome and may reflect ischemia induced liver cell injury within the context of an ischemia- reperfusion injury.'}) (input_keys={'question'}),
#   Example({'question': 'Is decreased expression of liver-type fatty acid-binding protein associated with poor prognosis in hepatocellular carcinoma?', 'answer': 'L-FABP was downregulated in HCC and could be served as a promising prognostic marker for HCC patients.'}) (input_keys={'question'}),
#   Example({'question': 'Does ephrin type-B receptor 4 activation reduce neointimal hyperplasia in human saphenous vein in vitro?', 'answer': 'Eph-B4 is present and functional in adult human saphenous veins, with intact downstream signaling pathways capable of NO release and prevention of neointimal hyperplasia in vitro. Adventitial delivery of ephrin-B2/Fc activates endothelial Eph-B4 in saphenous veins treated with arterial shear stress in vitro. These results suggest that stimulation of Eph-B4 function may be a candidate strategy for translation to human clinical trials designed to inhibit venous neointimal hyperplasia.'}) (input_keys={'question'}),
#   Example({'question': 'Are low serum levels of vitamin D associated with post-stroke depression?', 'answer': 'Serum vitamin D levels within 24 h after admission are found to be associated with PSD and may predict its development at 1 month post-stroke.'}) (input_keys={'question'}),
#   Example({'question': "Are polymorphisms near TBX5 and GDF7 associated with increased risk for Barrett 's esophagus?", 'answer': 'We identified 2 loci associated with risk of BE and provided data to support a further locus. The genes we found to be associated with risk for BE encode transcription factors involved in thoracic, diaphragmatic, and esophageal development or proteins involved in the inflammatory response.'}) (input_keys={'question'}),
#   Example({'question': 'Does danzhi Xiaoyao San ameliorate depressive-like behavior by shifting toward serotonin via the downregulation of hippocampal indoleamine 2,3-dioxygenase?', 'answer': 'DXS exhibited antidepressant-like effects on rats exposed to CUMS. DXS reduced IDO activity to shift the balance of the Kyn/5-HT pathway toward the 5-HT pathway.'}) (input_keys={'question'}),
#   Example({'question': 'Is p63 more sensitive and specific than 34βE12 to differentiate adenocarcinoma of prostate from cancer mimickers?', 'answer': 'Basal cell markers can help to distinguish prostate adenocarcinoma from cancer mimickers.'}) (input_keys={'question'}),
#   Example({'question': 'Does poor sleep predict symptoms of depression and disability retirement due to depression?', 'answer': 'Lack of baseline diagnostic interviews; sleep quality based on self-report.'}) (input_keys={'question'}),
#   Example({'question': 'Are phospholipase C epsilon 1 ( PLCE1 ) haplotypes associated with increased risk of gastric cancer in Kashmir Valley?', 'answer': 'These results suggest that variation in PLCE1 may be associated with GC risk in Kashmir Valley.'}) (input_keys={'question'}),
#   Example({'question': 'Is tGFBI Expression in Cancer Stromal Cells Associated with Poor Prognosis and Hematogenous Recurrence in Esophageal Squamous Cell Carcinoma?', 'answer': 'High TGFBI expression in ESCC tissues could be a powerful biomarker of poor prognosis and hematogenous recurrence. TGFBI in stromal cells might be a promising molecular target for ESCC treatment.'}) (input_keys={'question'}),
#   Example({'question': 'Are autoimmune features associated with chronic antibiotic-refractory pouchitis?', 'answer': 'There is marked overlap of certain immune markers in patients with pouch dysfunction, especially those with CARP. Microsomal antibody expression and elevated IgG4-positive plasma cell infiltration were independent risk factors for CARP.'}) (input_keys={'question'}),
#   Example({'question': 'Does identical ATP1A3 mutation cause alternating hemiplegia of childhood and rapid-onset dystonia parkinsonism phenotypes?', 'answer': 'The discordance of these phenotypes suggests that there are other undiscovered environmental, genetic, or epigenetic factors influencing the development of alternating hemiplegia of childhood or rapid-onset dystonia parkinsonism.'}) (input_keys={'question'}),
#   Example({'question': 'Does metabolic control analysis of the Trypanosoma cruzi peroxide detoxification pathway identify tryparedoxin as a suitable drug target?', 'answer': 'These quantitative kinetic and metabolic analyses pointed out to TXN as a convenient drug target due to its low catalytic efficiency, high control on the flux of peroxide detoxification and role as provider of reducing equivalents to the two main peroxidases in the parasite.'}) (input_keys={'question'}),
#   Example({'question': 'Is basal Flt1 tyrosine kinase activity a positive regulator of endothelial survival and vascularization during zebrafish embryogenesis?', 'answer': 'Flt1-tyrosine kinase (TK) activity contributed significantly in endothelial cells survival and vascular development during embryo angiogenesis in zebrafish by engaging PI3K/Akt pathway.'}) (input_keys={'question'}),
#   Example({'question': 'Do immunizations with hepatitis B viral antigens and a TLR7/8 agonist adjuvant induce antigen-specific immune responses in HBV-transgenic mice?', 'answer': 'Immunization with CL097-conjugated HBV-Ag reversed immune tolerance in HBV-Tg mice and induced antigen-specific immune responses. TLR7/8 agonists appear to be potent adjuvants for the induction of antigen-specific Th1 responses in an immune tolerant state.'}) (input_keys={'question'}),
#   Example({'question': 'Are lobar microbleeds associated with a decline in executive functioning in older adults?', 'answer': "Lobar microbleeds, a marker of cerebral amyloid angiopathy, are associated with an accelerated rate of executive function decline. The presence of cerebral amyloid angiopathy may be an important source of cognitive decline in aging. Future work should examine how cerebral amyloid angiopathy interacts with neurodegenerative processes, such as Alzheimer's disease."}) (input_keys={'question'}),
#   Example({'question': 'Is self-reported physical activity in smoking pre-cessation a protective factor against relapse for all?', 'answer': 'Previous quit attempts and professional activity were positive predictors of smoking abstinence, with alcohol use disorder a negative predictor. PA was not found to be a significant predictor of smoking relapse, with only a positive interaction term seen for persons on antidepressant treatment. (Am J Addict 2014;XX:1-7).'}) (input_keys={'question'}),
#   Example({'question': 'Is breathlessness at rest the dominant presentation of patients admitted with heart failure?', 'answer': 'Many patients admitted with HF are CARBOSE. Shortness of breath at rest may be more alarming, but those who are CARBOSE have a worse prognosis, perhaps reflecting more severe right heart dysfunction. Clinical trials of hospitalized HF may inappropriately exclude patients if they focus on shortness of breath at rest rather than peripheral congestion.'}) (input_keys={'question'}),
#   Example({'question': 'Is delayed duodenal stump blow-out following total gastrectomy for cancer : Heightened awareness for the continued presence of the surgical past in the present the key to a successful duodenal stump disruption management . A case report?', 'answer': 'Several strategies have been proposed for the successful management post-gastrectomy duodenal stump disruption however; its treatment planning is absolutely determined by the presence or not of generalized peritonitis and hemodynamic instability with hostile abdomen. In such scenario, urgent reoperation is mandatory and the damage control principle should govern the operative treatment.'}) (input_keys={'question'}),
#   Example({'question': 'Are lipoprotein phospholipase A2 mass and activity associated with the diagnosis of acute brain ischemia?', 'answer': 'The results of our study do not support the early measurement of Lp-PLA2 mass or activity levels for confirming an ischemic etiology in patients experiencing minor or transient focal neurological events.'}) (input_keys={'question'}),
#   Example({'question': 'Is osteoprotegerin associated with subclinical left ventricular systolic dysfunction in diabetic hypertensive patients : a speckle tracking study?', 'answer': 'Plasma OPG values could predict subclinical LV systolic dysfunction in diabetic hypertensive patients.'}) (input_keys={'question'}),
#   Example({'question': 'Do a new model for the standardization of experimental burn wounds?', 'answer': 'This is a safe, reliable, easy to construct and use model that has the ability to produce a regular and uniform reproducible burn due to precise temperature control associated with standardized animal positioning.'}) (input_keys={'question'}),
#   Example({'question': 'Does circulating atrial natriuretic peptide genetic association study identify a novel gene cluster associated with stroke in whites?', 'answer': 'This is the first large-scale genetic association study of circulating NT-proANP levels performed with replication and functional assessment that identified genetic variants in the MTHFR-CLCN6-NPPA-NPPB cluster to be significantly associated with NT-proANP levels. The clinical significance of this variation is related to lower NT-proANP levels, higher blood pressures, and an increased risk of stroke in the general community.'}) (input_keys={'question'}),
#   Example({'question': 'Do whole-genome sequencing and epidemiological analysis provide evidence for cross-transmission of mycobacterium abscessus in a cohort of pediatric cystic fibrosis patients?', 'answer': 'We have not demonstrated cross-transmission of M. abscessus within our hospital, except between 1 sibling pair. Alternative routes of acquisition of M. abscessus infection, in particular the environment, require further investigation.'}) (input_keys={'question'}),
#   Example({'question': 'Are high Atopobium vaginae and Gardnerella vaginalis vaginal loads associated with preterm birth?', 'answer': 'High vaginal loads of A. vaginae and G. vaginalis are associated with late miscarriage and prematurity in high-risk pregnancies. A high vaginal load of A. vaginae (DNA level ≥10(8) copies/mL) identifies a population at high risk of preterm birth. Further studies that both screen for and then treat A. vaginae are needed.'}) (input_keys={'question'}),
#   Example({'question': 'Is cD30 expression a novel prognostic indicator in extranodal natural killer/T-cell lymphoma , nasal type?', 'answer': 'Our results showed that expression of CD30 was not related to response to treatment but was an independent prognostic factor for both OS and PFS in ENKTL, nasal type, which suggests a role for CD30 in the pathogenesis of this disease and may support the incorporation of anti-CD30-targeted therapy into the treatment paradigm for ENKTL.'}) (input_keys={'question'}),
#   Example({'question': 'Do [ Clinical study on continuous plasma filtration absorption treatment for burn sepsis ]?', 'answer': 'CPFA, which combines hemoabsorption and hemofiltration, can facilitate the treatment of burn sepsis by decreasing the level of pro-inflammatory cytokines efficiently, alleviating systemic inflammatory response, and improving the immune status.'}) (input_keys={'question'}),
#   Example({'question': 'Do [ Perinatal variables from newborns of Aymara mothers suggest a genetic adaptation to high altitude ]?', 'answer': 'Altitude of residence is related to a decrease in perinatal variables that proved to be less pronounced in newborns of mothers with a higher degree of Aymara ancestry. RESULTS suggest a genetic adaptation to hypoxia that could be related to candidate genes linked to the capture, transport or utilization of oxygen.'}) (input_keys={'question'}),
#   Example({'question': 'Is 25-hydroxyvitamin D status associated with chronic cerebral small vessel disease?', 'answer': '25(OH)D is inversely associated with lacunes, white matter hyperintensity, and deep CMB. Our findings suggest that 25(OH)D is linked to small vessel disease, and in future trials it should be tested whether 25(OH)D supplementation can prevent small vessel disease.'}) (input_keys={'question'}),
#   Example({'question': 'Is cD133-positive tumor cell content a predictor of early recurrence in colorectal cancer?', 'answer': 'These findings indicate that CD133 is a valid marker for identifying cancer stem cells from fresh surgically resected colorectal cancer tissues. Furthermore, we successfully established a living tumor tissue bank using surgically resected colorectal tissues with a viability of >70%.'}) (input_keys={'question'}),
#   Example({'question': 'Does traumatic brain injury induce neuroinflammation and neuronal degeneration that is associated with escalated alcohol self-administration in rats?', 'answer': 'These results show an association between post-TBI escalation of alcohol drinking and marked localized neuroinflammation at the site of injury. Moreover, these results highlight the relevance of baseline alcohol preference in determining post-TBI alcohol drinking. Further investigation to determine the contribution of neuroinflammation to increased alcohol drinking post-TBI is warranted.'}) (input_keys={'question'}),
#   Example({'question': 'Does maternal undernutrition induce premature reproductive senescence in adult female rat offspring?', 'answer': 'Our data indicate that the maternal nutritional environment programs the reproductive potential of the offspring through alteration of the hypothalamic-pituitary-gonadal axis. The premature reproductive senescence in LBW offspring could be secondary to the development of obesity and hyperleptinemia in these animals in adult life.'}) (input_keys={'question'}),
#   Example({'question': 'Does granulocyte colony-stimulating factor prevent loss of spermatogenesis after sterilizing busulfan chemotherapy?', 'answer': 'These results demonstrate that G-CSF protects spermatogenesis from gonadotoxic insult (busulfan) in rodents, and this may occur via direct action on CSF3R+ undifferentiated spermatogonia. G-CSF treatment might be an effective adjuvant therapy to preserve male fertility in cancer patients receiving sterilizing treatments.'}) (input_keys={'question'}),
#   Example({'question': 'Is saikosaponin b2 a naturally occurring terpenoid that efficiently inhibits hepatitis C virus entry?', 'answer': 'Due to its potency, SSb2 may be of value for development as an antagonist of HCV entry and could be explored as prophylactic treatment during the course of liver transplantation.'}) (input_keys={'question'}),
#   Example({'question': 'Does autotaxin activity have a high accuracy to diagnose intrahepatic cholestasis of pregnancy?', 'answer': 'Increased serum autotaxin activity represents a highly sensitive, specific and robust diagnostic marker of ICP, distinguishing ICP from other pruritic disorders of pregnancy and pregnancy-related liver diseases. Pregnancy and oral contraception increase serum autotaxin to a much lesser extent than ICP.'}) (input_keys={'question'}),
#   Example({'question': 'Does a dedicated research program increase the quantity and quality of orthopaedic resident publications?', 'answer': 'Currently in the United States, there are no standard policies or requirements that dictate how research should be incorporated in orthopaedic surgery residency training programs. The results of our study suggest that implementation of a dedicated resident research program improves the quantity and to some extent quality of orthopaedic resident research publications, but this effect did not persist after graduation.'}) (input_keys={'question'}),
#   Example({'question': 'Does cationic Nanogel-mediated Runx2 and Osterix siRNA Delivery decrease Mineralization in MC3T3 Cells?', 'answer': 'Although mRNA and protein knockdown were confirmed as a result of RNAi treatments against Runx2 and Osx, complete elimination of mineralization processes was not achieved. RNAi targeting mid- and late-stage osteoblast differentiation markers such as ALP, osteocalcin, osteopontin, and bone sialoprotein) may produce the desired RNAi-nanogel nanostructured polymer HO prophylaxis.'}) (input_keys={'question'}),
#   Example({'question': 'Do no sex differences exist in posterior condylar offsets of the knee?', 'answer': 'Results of our study showed that knees in males exhibited greater posterior condylar offset and greater total condylar height at the medial and lateral femoral condyles, however, there were no sex differences in the ratio of posterior condylar offset to condylar height at either condyle.'}) (input_keys={'question'}),
#   Example({'question': 'Do gene polymorphisms of stress hormone and cytokine receptors associate with immunomodulatory profile and psychological measurement?', 'answer': 'The data support the notion that gene polymorphisms from various components of the psychoneuroendocrine-immune network may be useful as biomarkers to categorize individual stress-associated immune responses.'}) (input_keys={'question'}),
#   Example({'question': 'Does housing temperature influence the pattern of heat shock protein induction in mice following mild whole body hyperthermia?', 'answer': 'Taken together, these data show that housing temperature significantly influences the expression of HSPs in mice after whole body heating and thus should be considered when stress responses are studied in mice.'}) (input_keys={'question'}),
#   Example({'question': 'Does intra-articular injection of synthetic microRNA-210 accelerate avascular meniscal healing in rat medial meniscal injured model?', 'answer': 'An intra-articular injection of ds miR-210 was effective in the healing of the damaged white zone meniscus through promotion of the collagen type 2 production from meniscus cells and through upregulated of VEGF and FGF2 from synovial cells.'}) (input_keys={'question'}),
#   Example({'question': 'Does pRMT5 enhance generation of induced pluripotent stem cells from dairy goat embryonic fibroblasts via down-regulation of p53?', 'answer': 'This study provides an efficient model for future studies on mechanisms underlying goat somatic cell reprogramming and differentiation.'}) (input_keys={'question'}),
#   Example({'question': 'Do minimally invasive retroperitoneoscopic surgery for psoas abscess with thoracolumbar tuberculosis?', 'answer': 'The retroperitoneoscopic technique for PA gain advantages in terms of shorter hospital stay, minimal invasiveness, absence of radiation, quicker recovery to daily life compared with percutaneous drainage, and anterior or posterior debridement surgery. Despite the technique not been fully clinically proved, it seems to be a recommended option as an effective diagnostic and therapeutic technique for PA, especially with massive or complicated PA.'}) (input_keys={'question'})])

# %%
from dspy.evaluate.evaluate import Evaluate

evaluate = Evaluate(
    metric=mixed_metric, devset=devset, num_threads=1, display_progress=True, display_table=5
)
evaluate(uncompiled_rag)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Average Metric: 16.2783067018725 / 50  (32.6): 100%|██████████| 50/50 [01:22<00:00,  1.64s/it]
# <style type="text/css">
# #T_64ea6 th {
#   text-align: left;
# }
# #T_64ea6 td {
#   text-align: left;
# }
# #T_64ea6_row0_col0, #T_64ea6_row0_col1, #T_64ea6_row0_col2, #T_64ea6_row0_col3, #T_64ea6_row0_col4, #T_64ea6_row1_col0, #T_64ea6_row1_col1, #T_64ea6_row1_col2, #T_64ea6_row1_col3, #T_64ea6_row1_col4, #T_64ea6_row2_col0, #T_64ea6_row2_col1, #T_64ea6_row2_col2, #T_64ea6_row2_col3, #T_64ea6_row2_col4, #T_64ea6_row3_col0, #T_64ea6_row3_col1, #T_64ea6_row3_col2, #T_64ea6_row3_col3, #T_64ea6_row3_col4, #T_64ea6_row4_col0, #T_64ea6_row4_col1, #T_64ea6_row4_col2, #T_64ea6_row4_col3, #T_64ea6_row4_col4 {
#   text-align: left;
#   white-space: pre-wrap;
#   word-wrap: break-word;
#   max-width: 400px;
# }
# </style>
# <table id="T_64ea6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64ea6_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_64ea6_level0_col1" class="col_heading level0 col1" >example_answer</th>
#       <th id="T_64ea6_level0_col2" class="col_heading level0 col2" >context</th>
#       <th id="T_64ea6_level0_col3" class="col_heading level0 col3" >pred_answer</th>
#       <th id="T_64ea6_level0_col4" class="col_heading level0 col4" >mixed_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ea6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64ea6_row0_col0" class="data row0 col0" >Is increased time from neoadjuvant chemoradiation to surgery associated with higher pathologic complete response rates in esophageal cancer?</td>
#       <td id="T_64ea6_row0_col1" class="data row0 col1" >A longer interval between completion of neoadjuvant chemoradiation and surgery was associated with higher pathologic complete response rates without an impact on surgical morbidity.</td>
#       <td id="T_64ea6_row0_col2" class="data row0 col2" >['The interval between neoadjuvant chemoradiation treatment and surgery has been described as an important predictor of pathologic response to therapy in nonesophageal cancer sites. We...</td>
#       <td id="T_64ea6_row0_col3" class="data row0 col3" >Yes, increased time from neoadjuvant chemoradiation to surgery is associated with higher pathologic complete response rates in esophageal cancer.</td>
#       <td id="T_64ea6_row0_col4" class="data row0 col4" >✔️ [0.7792506814002991]</td>
#     </tr>
#     <tr>
#       <th id="T_64ea6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64ea6_row1_col0" class="data row1 col0" >Is epileptic focus localization based on resting state interictal MEG recordings feasible irrespective of the presence or absence of spikes?</td>
#       <td id="T_64ea6_row1_col1" class="data row1 col1" >Our preliminary results suggest that accurate localization of the epileptogenic focus may be accomplished using noninvasive spontaneous "resting-state" recordings of relatively brief duration and without...</td>
#       <td id="T_64ea6_row1_col2" class="data row1 col2" >['To investigate whether epileptogenic focus localization is possible based on resting state connectivity analysis of magnetoencephalographic (MEG) data. A multivariate autoregressive (MVAR) model was constructed...</td>
#       <td id="T_64ea6_row1_col3" class="data row1 col3" >Yes.</td>
#       <td id="T_64ea6_row1_col4" class="data row1 col4" >✔️ [0.0886337012052536]</td>
#     </tr>
#     <tr>
#       <th id="T_64ea6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64ea6_row2_col0" class="data row2 col0" >Does seminal Helicobacter pylori treatment improve sperm motility in infertile asthenozoospermic men?</td>
#       <td id="T_64ea6_row2_col1" class="data row2 col1" >H pylori treatment significantly improves sperm motility in infertile asthenozoospermic men with elevated seminal H pylori IgA.</td>
#       <td id="T_64ea6_row2_col2" class="data row2 col2" >['To assess the effect of treatment of seminal Helicobacter pylori in infertile asthenozoospermic men. In all, 223 infertile asthenozoospermic men were consecutively selected. They were...</td>
#       <td id="T_64ea6_row2_col3" class="data row2 col3" >Yes, treatment of seminal Helicobacter pylori in infertile asthenozoospermic men has been shown to improve sperm motility.</td>
#       <td id="T_64ea6_row2_col4" class="data row2 col4" >✔️ [0.8661220669746399]</td>
#     </tr>
#     <tr>
#       <th id="T_64ea6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64ea6_row3_col0" class="data row3 col0" >Does a migrating ciliary gate compartmentalize the site of axoneme assembly in Drosophila spermatids?</td>
#       <td id="T_64ea6_row3_col1" class="data row3 col1" >Our findings demonstrate that the ciliary gate can migrate away from the base of the cilium, thereby functioning independently of the centriole and of a...</td>
#       <td id="T_64ea6_row3_col2" class="data row3 col2" >['In most cells, the cilium is formed within a compartment separated from the cytoplasm. Entry into the ciliary compartment is regulated by a specialized gate...</td>
#       <td id="T_64ea6_row3_col3" class="data row3 col3" >Yes.</td>
#       <td id="T_64ea6_row3_col4" class="data row3 col4" >✔️ [0.06154946982860565]</td>
#     </tr>
#     <tr>
#       <th id="T_64ea6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64ea6_row4_col0" class="data row4 col0" >Is individual Public Transportation Accessibility Positively Associated with Self-Reported Active Commuting?</td>
#       <td id="T_64ea6_row4_col1" class="data row4 col1" >This study extends the knowledge about the driving forces of using public transportation for commuting by examining the individual public transportation accessibility. Findings suggest that...</td>
#       <td id="T_64ea6_row4_col2" class="data row4 col2" >['Active commuters have lower risk of chronic disease. Understanding which of the, to some extent, modifiable characteristics of public transportation that facilitate its use is...</td>
#       <td id="T_64ea6_row4_col3" class="data row4 col3" >Yes, individual public transportation accessibility is positively associated with self-reported active commuting.</td>
#       <td id="T_64ea6_row4_col4" class="data row4 col4" >✔️ [0.8073875308036804]</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style='
#                     text-align: center;
#                     font-size: 16px;
#                     font-weight: bold;
#                     color: #555;
#                     margin: 10px 0;'>
#                     ... 45 more rows not displayed ...
#                 </div>
# 32.56

# %% [markdown]
# ### Optimization
#
# We can now compile/optimized the DSPy program we created.
#
# This can be done using a teleprompter/optimizer, based on our metric and training set.
#
# In particular, `BootstrapFewShot` tries to improve the metric in the training set by adding few shot examples to the prompt.

# %%
from dspy.teleprompt import BootstrapFewShot

optimizer = BootstrapFewShot(metric=mixed_metric)

compiled_rag = optimizer.compile(RAG(), trainset=trainset)
# Out:
#  20%|██        | 4/20 [00:08<00:32,  2.04s/it]
# Bootstrapped 4 full traces after 5 examples in round 0.

# %% [markdown]
# ### Evaluate optimized RAG module
#
# Let's now see if the training has been successful, evaluating the compiled RAG module on the dev set.

# %%
evaluate = Evaluate(
    metric=mixed_metric, devset=devset, num_threads=1, display_progress=True, display_table=5
)
evaluate(compiled_rag)
# Out:
# Average Metric: 35.15759664177895 / 50  (70.3): 100%|██████████| 50/50 [01:34<00:00,  1.88s/it]
# <style type="text/css">
# #T_265e2 th {
#   text-align: left;
# }
# #T_265e2 td {
#   text-align: left;
# }
# #T_265e2_row0_col0, #T_265e2_row0_col1, #T_265e2_row0_col2, #T_265e2_row0_col3, #T_265e2_row0_col4, #T_265e2_row1_col0, #T_265e2_row1_col1, #T_265e2_row1_col2, #T_265e2_row1_col3, #T_265e2_row1_col4, #T_265e2_row2_col0, #T_265e2_row2_col1, #T_265e2_row2_col2, #T_265e2_row2_col3, #T_265e2_row2_col4, #T_265e2_row3_col0, #T_265e2_row3_col1, #T_265e2_row3_col2, #T_265e2_row3_col3, #T_265e2_row3_col4, #T_265e2_row4_col0, #T_265e2_row4_col1, #T_265e2_row4_col2, #T_265e2_row4_col3, #T_265e2_row4_col4 {
#   text-align: left;
#   white-space: pre-wrap;
#   word-wrap: break-word;
#   max-width: 400px;
# }
# </style>
# <table id="T_265e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_265e2_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_265e2_level0_col1" class="col_heading level0 col1" >example_answer</th>
#       <th id="T_265e2_level0_col2" class="col_heading level0 col2" >context</th>
#       <th id="T_265e2_level0_col3" class="col_heading level0 col3" >pred_answer</th>
#       <th id="T_265e2_level0_col4" class="col_heading level0 col4" >mixed_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_265e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_265e2_row0_col0" class="data row0 col0" >Is increased time from neoadjuvant chemoradiation to surgery associated with higher pathologic complete response rates in esophageal cancer?</td>
#       <td id="T_265e2_row0_col1" class="data row0 col1" >A longer interval between completion of neoadjuvant chemoradiation and surgery was associated with higher pathologic complete response rates without an impact on surgical morbidity.</td>
#       <td id="T_265e2_row0_col2" class="data row0 col2" >['The interval between neoadjuvant chemoradiation treatment and surgery has been described as an important predictor of pathologic response to therapy in nonesophageal cancer sites. We...</td>
#       <td id="T_265e2_row0_col3" class="data row0 col3" >Yes, increased time from neoadjuvant chemoradiation to surgery is associated with higher pathologic complete response rates in esophageal cancer.</td>
#       <td id="T_265e2_row0_col4" class="data row0 col4" >✔️ [0.7792506814002991]</td>
#     </tr>
#     <tr>
#       <th id="T_265e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_265e2_row1_col0" class="data row1 col0" >Is epileptic focus localization based on resting state interictal MEG recordings feasible irrespective of the presence or absence of spikes?</td>
#       <td id="T_265e2_row1_col1" class="data row1 col1" >Our preliminary results suggest that accurate localization of the epileptogenic focus may be accomplished using noninvasive spontaneous "resting-state" recordings of relatively brief duration and without...</td>
#       <td id="T_265e2_row1_col2" class="data row1 col2" >['To investigate whether epileptogenic focus localization is possible based on resting state connectivity analysis of magnetoencephalographic (MEG) data. A multivariate autoregressive (MVAR) model was constructed...</td>
#       <td id="T_265e2_row1_col3" class="data row1 col3" >Yes, epileptic focus localization based on resting state interictal MEG recordings is feasible irrespective of the presence or absence of spikes.</td>
#       <td id="T_265e2_row1_col4" class="data row1 col4" >✔️ [0.8550739049911499]</td>
#     </tr>
#     <tr>
#       <th id="T_265e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_265e2_row2_col0" class="data row2 col0" >Does seminal Helicobacter pylori treatment improve sperm motility in infertile asthenozoospermic men?</td>
#       <td id="T_265e2_row2_col1" class="data row2 col1" >H pylori treatment significantly improves sperm motility in infertile asthenozoospermic men with elevated seminal H pylori IgA.</td>
#       <td id="T_265e2_row2_col2" class="data row2 col2" >['To assess the effect of treatment of seminal Helicobacter pylori in infertile asthenozoospermic men. In all, 223 infertile asthenozoospermic men were consecutively selected. They were...</td>
#       <td id="T_265e2_row2_col3" class="data row2 col3" >Yes, seminal Helicobacter pylori treatment improved sperm motility in infertile asthenozoospermic men.</td>
#       <td id="T_265e2_row2_col4" class="data row2 col4" >✔️ [0.8639540672302246]</td>
#     </tr>
#     <tr>
#       <th id="T_265e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_265e2_row3_col0" class="data row3 col0" >Does a migrating ciliary gate compartmentalize the site of axoneme assembly in Drosophila spermatids?</td>
#       <td id="T_265e2_row3_col1" class="data row3 col1" >Our findings demonstrate that the ciliary gate can migrate away from the base of the cilium, thereby functioning independently of the centriole and of a...</td>
#       <td id="T_265e2_row3_col2" class="data row3 col2" >['In most cells, the cilium is formed within a compartment separated from the cytoplasm. Entry into the ciliary compartment is regulated by a specialized gate...</td>
#       <td id="T_265e2_row3_col3" class="data row3 col3" >Yes, a migrating ciliary gate compartmentalizes the site of axoneme assembly in Drosophila spermatids.</td>
#       <td id="T_265e2_row3_col4" class="data row3 col4" >✔️ [0.6595481634140015]</td>
#     </tr>
#     <tr>
#       <th id="T_265e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_265e2_row4_col0" class="data row4 col0" >Is individual Public Transportation Accessibility Positively Associated with Self-Reported Active Commuting?</td>
#       <td id="T_265e2_row4_col1" class="data row4 col1" >This study extends the knowledge about the driving forces of using public transportation for commuting by examining the individual public transportation accessibility. Findings suggest that...</td>
#       <td id="T_265e2_row4_col2" class="data row4 col2" >['Active commuters have lower risk of chronic disease. Understanding which of the, to some extent, modifiable characteristics of public transportation that facilitate its use is...</td>
#       <td id="T_265e2_row4_col3" class="data row4 col3" >Yes, individual public transportation accessibility is positively associated with self-reported active commuting.</td>
#       <td id="T_265e2_row4_col4" class="data row4 col4" >✔️ [0.8073875308036804]</td>
#     </tr>
#   </tbody>
# </table>
#                 <div style='
#                     text-align: center;
#                     font-size: 16px;
#                     font-weight: bold;
#                     color: #555;
#                     margin: 10px 0;'>
#                     ... 45 more rows not displayed ...
#                 </div>
# 70.32

# %% [markdown]
# Based on our simple metric, we got a significant improvement!

# %% [markdown]
# ### Inspect the optimized prompt
#
# Let's take a look at the few shot examples that made our results improve...

# %%
devset
# Out:
# [Example({'question': 'Is increased time from neoadjuvant chemoradiation to surgery associated with higher pathologic complete response rates in esophageal cancer?', 'answer': 'A longer interval between completion of neoadjuvant chemoradiation and surgery was associated with higher pathologic complete response rates without an impact on surgical morbidity.'}) (input_keys={'question'}),
#  Example({'question': 'Is epileptic focus localization based on resting state interictal MEG recordings feasible irrespective of the presence or absence of spikes?', 'answer': 'Our preliminary results suggest that accurate localization of the epileptogenic focus may be accomplished using noninvasive spontaneous "resting-state" recordings of relatively brief duration and without the need to capture definite interictal and/or ictal abnormalities.'}) (input_keys={'question'}),
#  Example({'question': 'Does seminal Helicobacter pylori treatment improve sperm motility in infertile asthenozoospermic men?', 'answer': 'H pylori treatment significantly improves sperm motility in infertile asthenozoospermic men with elevated seminal H pylori IgA.'}) (input_keys={'question'}),
#  Example({'question': 'Does a migrating ciliary gate compartmentalize the site of axoneme assembly in Drosophila spermatids?', 'answer': 'Our findings demonstrate that the ciliary gate can migrate away from the base of the cilium, thereby functioning independently of the centriole and of a static interaction with the axoneme to compartmentalize the site of axoneme assembly.'}) (input_keys={'question'}),
#  Example({'question': 'Is individual Public Transportation Accessibility Positively Associated with Self-Reported Active Commuting?', 'answer': 'This study extends the knowledge about the driving forces of using public transportation for commuting by examining the individual public transportation accessibility. Findings suggest that transportation accessibility supports active commuting and planning of improved public transit accessibility has thus a potential of providing health benefits to commuters.'}) (input_keys={'question'}),
#  Example({'question': 'Is congenital penile pathology associated with abnormal development of the dartos muscle : a prospective study of primary penile surgery at a tertiary referral center?', 'answer': 'Congenital penile pathology (hypospadias, buried penis) is associated with structural anomalies in dartos tissue. Further research is needed to unveil the pathophysiology of the condition.'}) (input_keys={'question'}),
#  Example({'question': 'Is δNp63 expression a protective factor of progression in clinical high grade T1 bladder cancer?', 'answer': 'ΔNp63 expression is a favorable prognostic factor in clinically high grade T1 bladder cancer. This marker identifies patients at low risk for progression who could benefit from conservative therapy with transurethral bladder tumor resection and bacillus Calmette-Guérin, avoiding over treatment with immediate radical cystectomy.'}) (input_keys={'question'}),
#  Example({'question': 'Do high levels of procalcitonin in the early phase after pediatric liver transplantation indicate poor postoperative outcome?', 'answer': 'High levels of PCT after pLTx are an early indicator of poor postoperative outcome and may reflect ischemia induced liver cell injury within the context of an ischemia- reperfusion injury.'}) (input_keys={'question'}),
#  Example({'question': 'Is decreased expression of liver-type fatty acid-binding protein associated with poor prognosis in hepatocellular carcinoma?', 'answer': 'L-FABP was downregulated in HCC and could be served as a promising prognostic marker for HCC patients.'}) (input_keys={'question'}),
#  Example({'question': 'Does ephrin type-B receptor 4 activation reduce neointimal hyperplasia in human saphenous vein in vitro?', 'answer': 'Eph-B4 is present and functional in adult human saphenous veins, with intact downstream signaling pathways capable of NO release and prevention of neointimal hyperplasia in vitro. Adventitial delivery of ephrin-B2/Fc activates endothelial Eph-B4 in saphenous veins treated with arterial shear stress in vitro. These results suggest that stimulation of Eph-B4 function may be a candidate strategy for translation to human clinical trials designed to inhibit venous neointimal hyperplasia.'}) (input_keys={'question'}),
#  Example({'question': 'Are low serum levels of vitamin D associated with post-stroke depression?', 'answer': 'Serum vitamin D levels within 24 h after admission are found to be associated with PSD and may predict its development at 1 month post-stroke.'}) (input_keys={'question'}),
#  Example({'question': "Are polymorphisms near TBX5 and GDF7 associated with increased risk for Barrett 's esophagus?", 'answer': 'We identified 2 loci associated with risk of BE and provided data to support a further locus. The genes we found to be associated with risk for BE encode transcription factors involved in thoracic, diaphragmatic, and esophageal development or proteins involved in the inflammatory response.'}) (input_keys={'question'}),
#  Example({'question': 'Does danzhi Xiaoyao San ameliorate depressive-like behavior by shifting toward serotonin via the downregulation of hippocampal indoleamine 2,3-dioxygenase?', 'answer': 'DXS exhibited antidepressant-like effects on rats exposed to CUMS. DXS reduced IDO activity to shift the balance of the Kyn/5-HT pathway toward the 5-HT pathway.'}) (input_keys={'question'}),
#  Example({'question': 'Is p63 more sensitive and specific than 34βE12 to differentiate adenocarcinoma of prostate from cancer mimickers?', 'answer': 'Basal cell markers can help to distinguish prostate adenocarcinoma from cancer mimickers.'}) (input_keys={'question'}),
#  Example({'question': 'Does poor sleep predict symptoms of depression and disability retirement due to depression?', 'answer': 'Lack of baseline diagnostic interviews; sleep quality based on self-report.'}) (input_keys={'question'}),
#  Example({'question': 'Are phospholipase C epsilon 1 ( PLCE1 ) haplotypes associated with increased risk of gastric cancer in Kashmir Valley?', 'answer': 'These results suggest that variation in PLCE1 may be associated with GC risk in Kashmir Valley.'}) (input_keys={'question'}),
#  Example({'question': 'Is tGFBI Expression in Cancer Stromal Cells Associated with Poor Prognosis and Hematogenous Recurrence in Esophageal Squamous Cell Carcinoma?', 'answer': 'High TGFBI expression in ESCC tissues could be a powerful biomarker of poor prognosis and hematogenous recurrence. TGFBI in stromal cells might be a promising molecular target for ESCC treatment.'}) (input_keys={'question'}),
#  Example({'question': 'Are autoimmune features associated with chronic antibiotic-refractory pouchitis?', 'answer': 'There is marked overlap of certain immune markers in patients with pouch dysfunction, especially those with CARP. Microsomal antibody expression and elevated IgG4-positive plasma cell infiltration were independent risk factors for CARP.'}) (input_keys={'question'}),
#  Example({'question': 'Does identical ATP1A3 mutation cause alternating hemiplegia of childhood and rapid-onset dystonia parkinsonism phenotypes?', 'answer': 'The discordance of these phenotypes suggests that there are other undiscovered environmental, genetic, or epigenetic factors influencing the development of alternating hemiplegia of childhood or rapid-onset dystonia parkinsonism.'}) (input_keys={'question'}),
#  Example({'question': 'Does metabolic control analysis of the Trypanosoma cruzi peroxide detoxification pathway identify tryparedoxin as a suitable drug target?', 'answer': 'These quantitative kinetic and metabolic analyses pointed out to TXN as a convenient drug target due to its low catalytic efficiency, high control on the flux of peroxide detoxification and role as provider of reducing equivalents to the two main peroxidases in the parasite.'}) (input_keys={'question'}),
#  Example({'question': 'Is basal Flt1 tyrosine kinase activity a positive regulator of endothelial survival and vascularization during zebrafish embryogenesis?', 'answer': 'Flt1-tyrosine kinase (TK) activity contributed significantly in endothelial cells survival and vascular development during embryo angiogenesis in zebrafish by engaging PI3K/Akt pathway.'}) (input_keys={'question'}),
#  Example({'question': 'Do immunizations with hepatitis B viral antigens and a TLR7/8 agonist adjuvant induce antigen-specific immune responses in HBV-transgenic mice?', 'answer': 'Immunization with CL097-conjugated HBV-Ag reversed immune tolerance in HBV-Tg mice and induced antigen-specific immune responses. TLR7/8 agonists appear to be potent adjuvants for the induction of antigen-specific Th1 responses in an immune tolerant state.'}) (input_keys={'question'}),
#  Example({'question': 'Are lobar microbleeds associated with a decline in executive functioning in older adults?', 'answer': "Lobar microbleeds, a marker of cerebral amyloid angiopathy, are associated with an accelerated rate of executive function decline. The presence of cerebral amyloid angiopathy may be an important source of cognitive decline in aging. Future work should examine how cerebral amyloid angiopathy interacts with neurodegenerative processes, such as Alzheimer's disease."}) (input_keys={'question'}),
#  Example({'question': 'Is self-reported physical activity in smoking pre-cessation a protective factor against relapse for all?', 'answer': 'Previous quit attempts and professional activity were positive predictors of smoking abstinence, with alcohol use disorder a negative predictor. PA was not found to be a significant predictor of smoking relapse, with only a positive interaction term seen for persons on antidepressant treatment. (Am J Addict 2014;XX:1-7).'}) (input_keys={'question'}),
#  Example({'question': 'Is breathlessness at rest the dominant presentation of patients admitted with heart failure?', 'answer': 'Many patients admitted with HF are CARBOSE. Shortness of breath at rest may be more alarming, but those who are CARBOSE have a worse prognosis, perhaps reflecting more severe right heart dysfunction. Clinical trials of hospitalized HF may inappropriately exclude patients if they focus on shortness of breath at rest rather than peripheral congestion.'}) (input_keys={'question'}),
#  Example({'question': 'Is delayed duodenal stump blow-out following total gastrectomy for cancer : Heightened awareness for the continued presence of the surgical past in the present the key to a successful duodenal stump disruption management . A case report?', 'answer': 'Several strategies have been proposed for the successful management post-gastrectomy duodenal stump disruption however; its treatment planning is absolutely determined by the presence or not of generalized peritonitis and hemodynamic instability with hostile abdomen. In such scenario, urgent reoperation is mandatory and the damage control principle should govern the operative treatment.'}) (input_keys={'question'}),
#  Example({'question': 'Are lipoprotein phospholipase A2 mass and activity associated with the diagnosis of acute brain ischemia?', 'answer': 'The results of our study do not support the early measurement of Lp-PLA2 mass or activity levels for confirming an ischemic etiology in patients experiencing minor or transient focal neurological events.'}) (input_keys={'question'}),
#  Example({'question': 'Is osteoprotegerin associated with subclinical left ventricular systolic dysfunction in diabetic hypertensive patients : a speckle tracking study?', 'answer': 'Plasma OPG values could predict subclinical LV systolic dysfunction in diabetic hypertensive patients.'}) (input_keys={'question'}),
#  Example({'question': 'Do a new model for the standardization of experimental burn wounds?', 'answer': 'This is a safe, reliable, easy to construct and use model that has the ability to produce a regular and uniform reproducible burn due to precise temperature control associated with standardized animal positioning.'}) (input_keys={'question'}),
#  Example({'question': 'Does circulating atrial natriuretic peptide genetic association study identify a novel gene cluster associated with stroke in whites?', 'answer': 'This is the first large-scale genetic association study of circulating NT-proANP levels performed with replication and functional assessment that identified genetic variants in the MTHFR-CLCN6-NPPA-NPPB cluster to be significantly associated with NT-proANP levels. The clinical significance of this variation is related to lower NT-proANP levels, higher blood pressures, and an increased risk of stroke in the general community.'}) (input_keys={'question'}),
#  Example({'question': 'Do whole-genome sequencing and epidemiological analysis provide evidence for cross-transmission of mycobacterium abscessus in a cohort of pediatric cystic fibrosis patients?', 'answer': 'We have not demonstrated cross-transmission of M. abscessus within our hospital, except between 1 sibling pair. Alternative routes of acquisition of M. abscessus infection, in particular the environment, require further investigation.'}) (input_keys={'question'}),
#  Example({'question': 'Are high Atopobium vaginae and Gardnerella vaginalis vaginal loads associated with preterm birth?', 'answer': 'High vaginal loads of A. vaginae and G. vaginalis are associated with late miscarriage and prematurity in high-risk pregnancies. A high vaginal load of A. vaginae (DNA level ≥10(8) copies/mL) identifies a population at high risk of preterm birth. Further studies that both screen for and then treat A. vaginae are needed.'}) (input_keys={'question'}),
#  Example({'question': 'Is cD30 expression a novel prognostic indicator in extranodal natural killer/T-cell lymphoma , nasal type?', 'answer': 'Our results showed that expression of CD30 was not related to response to treatment but was an independent prognostic factor for both OS and PFS in ENKTL, nasal type, which suggests a role for CD30 in the pathogenesis of this disease and may support the incorporation of anti-CD30-targeted therapy into the treatment paradigm for ENKTL.'}) (input_keys={'question'}),
#  Example({'question': 'Do [ Clinical study on continuous plasma filtration absorption treatment for burn sepsis ]?', 'answer': 'CPFA, which combines hemoabsorption and hemofiltration, can facilitate the treatment of burn sepsis by decreasing the level of pro-inflammatory cytokines efficiently, alleviating systemic inflammatory response, and improving the immune status.'}) (input_keys={'question'}),
#  Example({'question': 'Do [ Perinatal variables from newborns of Aymara mothers suggest a genetic adaptation to high altitude ]?', 'answer': 'Altitude of residence is related to a decrease in perinatal variables that proved to be less pronounced in newborns of mothers with a higher degree of Aymara ancestry. RESULTS suggest a genetic adaptation to hypoxia that could be related to candidate genes linked to the capture, transport or utilization of oxygen.'}) (input_keys={'question'}),
#  Example({'question': 'Is 25-hydroxyvitamin D status associated with chronic cerebral small vessel disease?', 'answer': '25(OH)D is inversely associated with lacunes, white matter hyperintensity, and deep CMB. Our findings suggest that 25(OH)D is linked to small vessel disease, and in future trials it should be tested whether 25(OH)D supplementation can prevent small vessel disease.'}) (input_keys={'question'}),
#  Example({'question': 'Is cD133-positive tumor cell content a predictor of early recurrence in colorectal cancer?', 'answer': 'These findings indicate that CD133 is a valid marker for identifying cancer stem cells from fresh surgically resected colorectal cancer tissues. Furthermore, we successfully established a living tumor tissue bank using surgically resected colorectal tissues with a viability of >70%.'}) (input_keys={'question'}),
#  Example({'question': 'Does traumatic brain injury induce neuroinflammation and neuronal degeneration that is associated with escalated alcohol self-administration in rats?', 'answer': 'These results show an association between post-TBI escalation of alcohol drinking and marked localized neuroinflammation at the site of injury. Moreover, these results highlight the relevance of baseline alcohol preference in determining post-TBI alcohol drinking. Further investigation to determine the contribution of neuroinflammation to increased alcohol drinking post-TBI is warranted.'}) (input_keys={'question'}),
#  Example({'question': 'Does maternal undernutrition induce premature reproductive senescence in adult female rat offspring?', 'answer': 'Our data indicate that the maternal nutritional environment programs the reproductive potential of the offspring through alteration of the hypothalamic-pituitary-gonadal axis. The premature reproductive senescence in LBW offspring could be secondary to the development of obesity and hyperleptinemia in these animals in adult life.'}) (input_keys={'question'}),
#  Example({'question': 'Does granulocyte colony-stimulating factor prevent loss of spermatogenesis after sterilizing busulfan chemotherapy?', 'answer': 'These results demonstrate that G-CSF protects spermatogenesis from gonadotoxic insult (busulfan) in rodents, and this may occur via direct action on CSF3R+ undifferentiated spermatogonia. G-CSF treatment might be an effective adjuvant therapy to preserve male fertility in cancer patients receiving sterilizing treatments.'}) (input_keys={'question'}),
#  Example({'question': 'Is saikosaponin b2 a naturally occurring terpenoid that efficiently inhibits hepatitis C virus entry?', 'answer': 'Due to its potency, SSb2 may be of value for development as an antagonist of HCV entry and could be explored as prophylactic treatment during the course of liver transplantation.'}) (input_keys={'question'}),
#  Example({'question': 'Does autotaxin activity have a high accuracy to diagnose intrahepatic cholestasis of pregnancy?', 'answer': 'Increased serum autotaxin activity represents a highly sensitive, specific and robust diagnostic marker of ICP, distinguishing ICP from other pruritic disorders of pregnancy and pregnancy-related liver diseases. Pregnancy and oral contraception increase serum autotaxin to a much lesser extent than ICP.'}) (input_keys={'question'}),
#  Example({'question': 'Does a dedicated research program increase the quantity and quality of orthopaedic resident publications?', 'answer': 'Currently in the United States, there are no standard policies or requirements that dictate how research should be incorporated in orthopaedic surgery residency training programs. The results of our study suggest that implementation of a dedicated resident research program improves the quantity and to some extent quality of orthopaedic resident research publications, but this effect did not persist after graduation.'}) (input_keys={'question'}),
#  Example({'question': 'Does cationic Nanogel-mediated Runx2 and Osterix siRNA Delivery decrease Mineralization in MC3T3 Cells?', 'answer': 'Although mRNA and protein knockdown were confirmed as a result of RNAi treatments against Runx2 and Osx, complete elimination of mineralization processes was not achieved. RNAi targeting mid- and late-stage osteoblast differentiation markers such as ALP, osteocalcin, osteopontin, and bone sialoprotein) may produce the desired RNAi-nanogel nanostructured polymer HO prophylaxis.'}) (input_keys={'question'}),
#  Example({'question': 'Do no sex differences exist in posterior condylar offsets of the knee?', 'answer': 'Results of our study showed that knees in males exhibited greater posterior condylar offset and greater total condylar height at the medial and lateral femoral condyles, however, there were no sex differences in the ratio of posterior condylar offset to condylar height at either condyle.'}) (input_keys={'question'}),
#  Example({'question': 'Do gene polymorphisms of stress hormone and cytokine receptors associate with immunomodulatory profile and psychological measurement?', 'answer': 'The data support the notion that gene polymorphisms from various components of the psychoneuroendocrine-immune network may be useful as biomarkers to categorize individual stress-associated immune responses.'}) (input_keys={'question'}),
#  Example({'question': 'Does housing temperature influence the pattern of heat shock protein induction in mice following mild whole body hyperthermia?', 'answer': 'Taken together, these data show that housing temperature significantly influences the expression of HSPs in mice after whole body heating and thus should be considered when stress responses are studied in mice.'}) (input_keys={'question'}),
#  Example({'question': 'Does intra-articular injection of synthetic microRNA-210 accelerate avascular meniscal healing in rat medial meniscal injured model?', 'answer': 'An intra-articular injection of ds miR-210 was effective in the healing of the damaged white zone meniscus through promotion of the collagen type 2 production from meniscus cells and through upregulated of VEGF and FGF2 from synovial cells.'}) (input_keys={'question'}),
#  Example({'question': 'Does pRMT5 enhance generation of induced pluripotent stem cells from dairy goat embryonic fibroblasts via down-regulation of p53?', 'answer': 'This study provides an efficient model for future studies on mechanisms underlying goat somatic cell reprogramming and differentiation.'}) (input_keys={'question'}),
#  Example({'question': 'Do minimally invasive retroperitoneoscopic surgery for psoas abscess with thoracolumbar tuberculosis?', 'answer': 'The retroperitoneoscopic technique for PA gain advantages in terms of shorter hospital stay, minimal invasiveness, absence of radiation, quicker recovery to daily life compared with percutaneous drainage, and anterior or posterior debridement surgery. Despite the technique not been fully clinically proved, it seems to be a recommended option as an effective diagnostic and therapeutic technique for PA, especially with massive or complicated PA.'}) (input_keys={'question'})]

# %%
lm.inspect_history(n=1)
# Out:
# Answer questions with short factoid answers.
#
# ---
#
# Question: Do tumor-infiltrating immune cell profiles and their change after neoadjuvant chemotherapy predict response and prognosis of breast cancer?
# Answer: Breast cancer immune cell subpopulation profiles, determined by immunohistochemistry-based computerized analysis, identify groups of patients characterized by high response (in the pre-treatment setting) and poor prognosis (in the post-treatment setting). Further understanding of the mechanisms underlying the distribution of immune cells and their changes after chemotherapy may contribute to the development of new immune-targeted therapies for breast cancer.
#
# Question: Do large portion sizes increase bite size and eating rate in overweight women?
# Answer: Increasing portion size led to a larger bite size and faster eating rate, but a slower reduction in eating speed during the meal. These changes may underlie greater energy intakes with exposure to large portions. Interventions to reduce bite size and slow eating rate may provide individuals with strategies to reduce the risk of overconsumption.
#
# Question: Are secretory phospholipases A2 secreted from ciliated cells and increase mucin and eicosanoid secretion from goblet cells?
# Answer: sPLA2 are secreted from ciliated cells and appear to induce mucin and cysLT secretion from goblet cells, strongly suggesting that airway goblet cells are proinflammatory effector cells.
#
# Question: Are reasons why erupted third molars extracted in a public university in Mexico?
# Answer: Women and patients 18 to 34 years of age had erupted 3M extracted more frequently, primarily for prosthetic reasons. The age profile indicated a trend in demand for services that differ from those of overall tooth extractions, but not for the trend across gender.
#
# Question: Does increased Syk phosphorylation lead to overexpression of TRAF6 in peripheral B cells of patients with systemic lupus erythematosus?
# Answer: Our results suggest that the activated Syk-mediated TRAF6 pathway leads to aberrant activation of B cells in SLE, and also highlight Syk as a potential target for B-cell-mediated processes in SLE.
#
# Question: Are routine preoperative restaging CTs after neoadjuvant chemoradiation for locally advanced rectal cancer low yield : a retrospective case study?
# Answer: Because of the financial costs and established risks of intravenous contrast and cumulative radiation exposure, it may be advisable to take a more selective approach to preoperative imaging. Larger, prospective studies may enable identification of an at-risk cohort who would benefit most from restaging CT.
#
# Question: Does the Boston keratoprosthesis provide a wide depth of focus?
# Answer: The KPro's wide depth-of-focus makes the visual acuity less dependent on an exact refractive correction at distance and explains the 'pseudoaccomodation' experienced by these patients. This is primarily due to the small pupil diameter of the KPro. The current manufacturing steps in 0.50 dioptre increments appears to be sufficient.
#
# Question: Do obese patients with idiopathic pulmonary fibrosis have a higher 90-day mortality risk with bilateral lung transplantation?
# Answer: Our results suggest that obese patients who receive a BLT may be at higher risk of 90-day mortality compared with patients of normal weight. Further study is needed to obtain more detailed information about comorbidities and other risk factors for early death that are not included in the OPTN database.
#
# Question: Is admission hyperglycemia associated with failed reperfusion following fibrinolytic therapy in patients with STEMI : results of a retrospective study?
# Answer: In patients with STEMI who undergo FT, admission hyperglycemia is an independent predictor of the failure of fibrinolysis.
#
# Question: Is hidradenitis suppurativa a systemic disease with substantial comorbidity burden : a chart-verified case-control analysis?
# Answer: Control subjects were not validated for absence of HS and comorbidity validation was not performed for either group.
#
# Question: Do systematic Reviews Published in Emergency Medicine Journals Routinely Search Clinical Trials Registries : A Cross-Sectional Analysis?
# Answer: Systematic reviews published in emergency medicine journals do not routinely include searches of clinical trials registries. By helping authors identify unpublished trial data, the addition of registry searches may improve the validity of systematic reviews.
#
# Question: Does promoter variant rs2301228 on the neural cell adhesion molecule 1 gene confer risk of schizophrenia in Han Chinese?
# Answer: Our results provide direct evidence for NCAM1 as a susceptibility gene for schizophrenia, which offers support to a neurodevelopmental model and neuronal connectivity hypothesis in the onset of schizophrenia.
#
# ---
#
# Follow the following format.
#
# Context: may contain relevant facts
#
# Question: ${question}
#
# Reasoning: Let's think step by step in order to ${produce the answer}. We ...
#
# Answer: short and precise answer
#
# ---
#
# Context:
# [1] «Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 innate lymphoid cells (ILC2s) represent a recently discovered cell population which has been implicated in driving Th2 inflammation in CRS; however, their relationship with clinical disease characteristics has yet to be investigated. The aim of this study was to identify ILC2s in sinus mucosa in patients with CRS and controls and compare ILC2s across characteristics of disease. A cross-sectional study of patients with CRS undergoing endoscopic sinus surgery was conducted. Sinus mucosal biopsies were obtained during surgery and control tissue from patients undergoing pituitary tumour resection through transphenoidal approach. ILC2s were identified as CD45(+) Lin(-) CD127(+) CD4(-) CD8(-) CRTH2(CD294)(+) CD161(+) cells in single cell suspensions through flow cytometry. ILC2 frequencies, measured as a percentage of CD45(+) cells, were compared across CRS phenotype, endotype, inflammatory CRS subtype and other disease characteristics including blood eosinophils, serum IgE, asthma status and nasal symptom score. 35 patients (40% female, age 48 ± 17 years) including 13 with eosinophilic CRS (eCRS), 13 with non-eCRS and 9 controls were recruited. ILC2 frequencies were associated with the presence of nasal polyps (P = 0.002) as well as high tissue eosinophilia (P = 0.004) and eosinophil-dominant CRS (P = 0.001) (Mann-Whitney U). They were also associated with increased blood eosinophilia (P = 0.005). There were no significant associations found between ILC2s and serum total IgE and allergic disease. In the CRS with nasal polyps (CRSwNP) population, ILC2s were increased in patients with co-existing asthma (P = 0.03). ILC2s were also correlated with worsening nasal symptom score in CRS (P = 0.04).»
# [2] «Allergic airway inflammation is triggered by allergen exposure through several steps including release of IL-33, which promotes cytokine (IL-5, IL-13) production by type 2 innate lymphoid cells (ILC2s). MicroRNA (miR)-155 has recently been described to regulate adaptive responses in allergic inflammation. However, the role of miR-155 in the regulation of ILC2s remains unexplored. We sought to elucidate the contribution of miR-155 in ILC2 expansion using experimental murine models of allergic airway inflammation. To determine the role of miR-155 in the regulation of ILC2s in allergic airway inflammation, miR-155 deficient (miR-155 miR-155 was 10-fold upregulated in WT-derived ILC2s in response to IL-33. Furthermore, miR-155»
# [3] «The mechanisms and immune pathways associated with chronic rhinosinusitis (CRS) are not fully understood. Immunological changes during acute exacerbation of CRS may provide valuable clues to the pathogenesis and perpetuation of the disease. To characterize local and systemic immune responses associated with acute worsening of sinonasal symptoms during exacerbation in CRS with nasal polyps (CRSwNP) compared to controls. This was a non-interventional prospective study of individuals with CRSwNP and normal controls. Subjects underwent a baseline visit with collection of nasal secretions, nasal washes, and serum specimens. Within 3 days of acute worsening of sinonasal symptoms, subjects underwent a study visit, followed by a post-visit 2 weeks later. The sinonasal outcome test-22 (SNOT-22) scores and immunological parameters in the specimens were analysed using a novel, unsupervised learning method and by conventional univariate analysis. Both CRSwNP patients and control subjects showed a significant increase in SNOT-22 scores during acute exacerbation. Increased nasal levels of IL-6, IL-5, and eosinophil major basic protein were observed in CRSwNP patients. A network analysis of serum specimens revealed changes in a set of immunological parameters, which are distinctly associated with CRSwNP but not with controls. In particular, systemic increases in VEGF and GM-CSF levels were notable and were validated by a conventional analysis.»
#
# Question: Are group 2 innate lymphoid cells ( ILC2s ) increased in chronic rhinosinusitis with nasal polyps or eosinophilia?
#
# Reasoning: Let's think step by step in order to produce the answer. We have data from a study that compared ILC2 frequencies in patients with CRS with nasal polyps or eosinophilia to controls.
#
# Answer: Yes, ILC2 frequencies were found to be increased in patients with chronic rhinosinusitis with nasal polyps and eosinophilia.
#
# ---
#
# Context:
# [1] «Phosphatidylethanolamine N-methyltransferase (PEMT), a liver enriched enzyme, is responsible for approximately one third of hepatic phosphatidylcholine biosynthesis. When fed a high-fat diet (HFD), Pemt(-/-) mice are protected from HF-induced obesity; however, they develop steatohepatitis. The vagus nerve relays signals between liver and brain that regulate peripheral adiposity and pancreas function. Here we explore a possible role of the hepatic branch of the vagus nerve in the development of diet induced obesity and steatohepatitis in Pemt(-/-) mice. 8-week old Pemt(-/-) and Pemt(+/+) mice were subjected to hepatic vagotomy (HV) or capsaicin treatment, which selectively disrupts afferent nerves, and were compared to sham-operated or vehicle-treatment, respectively. After surgery, mice were fed a HFD for 10 weeks. HV abolished the protection against the HFD-induced obesity and glucose intolerance in Pemt(-/-) mice. HV normalized phospholipid content and prevented steatohepatitis in Pemt(-/-) mice. Moreover, HV increased the hepatic anti-inflammatory cytokine interleukin-10, reduced chemokine monocyte chemotactic protein-1 and the ER stress marker C/EBP homologous protein. Furthermore, HV normalized the expression of mitochondrial electron transport chain proteins and of proteins involved in fatty acid synthesis, acetyl-CoA carboxylase and fatty acid synthase in Pemt(-/-) mice. However, disruption of the hepatic afferent vagus nerve by capsaicin failed to reverse either the protection against the HFD-induced obesity or the development of HF-induced steatohepatitis in Pemt(-/-) mice.»
# [2] «Nonalcoholic steatohepatitis (NASH) is associated with cirrhosis and hepatocellular carcinoma. Reactive oxygen species (ROS) and reactive nitrogen species (RNS) play key roles in the development of the disease. However, the therapeutic target of NASH has not been fully defined and new treatments are needed. We investigated the protective effects of the antioxidant indole-derived NecroX-7 in a NASH mouse model using leptin-deficient ob/ob and methionine- and choline-deficient (MCD) diet-fed ob/ob mice. Six-week-old male mice were divided into three groups: ob/+ mice, ob/ob mice treated with vehicle and ob/ob mice treated daily with NecroX-7 (20 mg/kg) for 4 weeks. To study the effects of NecroX-7 in a fibrosis model, NASH was induced by feeding ob/ob mice an MCD diet. The effects of NecroX-7 on NASH progression were evaluated using biochemical, histological and molecular markers. NecroX-7-treated ob/ob mice had a marked decrease in serum aspartate aminotransferase and alanine transaminase compared with vehicle-treated controls. Interestingly, hepatic steatosis and lipid peroxidation were significantly improved by NecroX-7 treatment. NecroX-7 inhibited tert-butylhydroperoxide- and H2 O2 -induced mitochondrial ROS/RNS in primary hepatocytes and attenuated mitochondrial dysfunction in vitro and in vivo. Furthermore, NecroX-7-treated mice exhibited fewer infiltrating macrophages and reduced hepatic tumour necrosis factor-alpha expression. Hepatic fibrosis in MCD-fed ob/ob mice was significantly decreased by NecroX-7 treatment.»
# [3] «The ability of a treatment method to interfere with tinnitus-related neural activity patterns, such as cortical gamma rhythms, has been suggested to indicate its potential in relieving tinnitus. Therapeutic modulation of gamma-band oscillations with vagus nerve stimulation has been recently reported in epileptic patients. The aim of this study was to investigate the effects of transcutaneous vagus nerve stimulation (tVNS) on neural oscillatory patterns. We calculated the power spectral density and synchrony of magnetoencephalography recordings during auditory stimulation in seven tinnitus patients and eight normal-hearing control subjects. Comparisons between subject groups were performed to reveal electrophysiological markers of tinnitus. tVNS-specific effects within each group were studied by comparing recording blocks with and without tVNS. We also investigated the correlation of each measure with individual ratings of tinnitus distress, as measured by the tinnitus handicap inventory questionnaire. Tinnitus patients differed from controls in the baseline condition (no tVNS applied), measured by both cortical oscillatory power and synchronization, particularly at beta and gamma frequencies. Importantly, we found tVNS-induced changes in synchrony, correlating strongly with tinnitus handicap inventory scores, at whole-head beta-band (r = -0.857, p = 0.007), whole-head gamma-band (r = -0.952, p = 0.0003), and frontal gamma-band (r = -0.952, p = 0.0003).»
#
# Question: Does vagus nerve contribute to the development of steatohepatitis and obesity in phosphatidylethanolamine N-methyltransferase deficient mice?
#
# Reasoning: Let's think step by step in order to produce the answer. We need to understand the role of the vagus nerve in the development of steatohepatitis and obesity in Pemt(-/-) mice.
#
# Answer: Yes, the hepatic branch of the vagus nerve contributes to the development of diet-induced obesity and steatohepatitis in Pemt(-/-) mice.
#
# ---
#
# Context:
# [1] «Psammaplin A (PsA) is a natural product isolated from marine sponges, which has been demonstrated to have anticancer activity against several human cancer cell lines via the induction of cell cycle arrest and apoptosis. New drugs that are less toxic and more effective against multidrug-resistant cancers are urgently needed. We tested cell proliferation, cell cycle progression and autophagic cell death pathway in doxorubicin-resistant MCF-7 (MCF-7/adr) human breast cancer cells. The potency of PsA was further determined using an in vivo xenograft model.»
# [2] «The purpose of this study was to investigate the relationship between huntingtin-associated protein1 (HAP1) gene and radiation therapy of breast cancer cells. HAP1 gene was transfected into breast cancer MCF-7 cells, which was confirmed by quantitative reverse transcription-polymerase chain reaction analysis (qRT-PCR) and Western blot in vitro. The changes of cell radiosensitivity were assessed by colony formation assay. Apoptosis were examined by flow cytometry. The expressions of two radiation-induced genes were evaluated by Western blot. Tumor growth was investigated in nude mice xenograft models in vivo. Our data showed that HAP1 gene expression was significantly increased in HAP1-transfected MCF-7 cells in comparison with the parental cells or negative control cells. The survival rate in MCF-7/HAP1 cells was significantly decreased after irradiation (0, 2, 4, 6, 8Gy), compared to cells in MCF-7 and MCF-7/Pb groups in vitro. HAP1 gene increased apoptosis in MCF-7 cells after irradiation. Additionally, the tumor volume and weight in MCF-7/HAP1+RT group were observably lower than in MCF-7/HAP1 group and MCF-7/Pb+RT group.»
# [3] «Due to the chemo resistant nature of cancer cells and adverse effects of current therapies, researchers are looking for the most efficient therapeutic approach which has the lowest side effects and the highest toxicity on cancer cells. The aim of the present study was to investigate the synergic effect of Urtica dioica extract in combination with paclitaxel on cell death and invasion of human breast cancer MDA-MB-468 cell line. To determine the cytotoxic effects of Urtica dioica extract with paclitaxel, MTT assay was performed. The scratch test was exploited to assess the effects of Urtica dioica, Paclitaxel alone and combination on migration of cancer cells. The expression levels of snail-1, ZEB1, ZEB2, twist, Cdc2, cyclin B1 and Wee1 genes were quantified using qRT-PCR and western blot performed for snail-1expression. The effects of plant extract, Paclitaxel alone and combination on different phases of cell cycle was analyzed using flow cytometry. Results of MTT assay showed that Urtica dioica significantly destroyed cancer cells. Interestingly, Concurrent use of Urtica dioica extract with paclitaxel resulted in decreased IC50 dose of paclitaxel. Moreover, findings of scratch assay exhibited the inhibitory effects of Urtica dioica, Paclitaxel alone and combination on migration of MDA-MB-468 cell line. Our findings also demonstrated that the extract substantially decreased the Snail-1 and related gene expression. Ultimately, Cell cycle arrest occurred at G2/M phase post-treatment by deregulating Cdc2 and wee1.»
#
# Question: Does psammaplin A induce Sirtuin 1-dependent autophagic cell death in doxorubicin-resistant MCF-7/adr human breast cancer cells and xenografts?
#
# Reasoning: Let's think step by step in order to produce the answer. We know that Psammaplin A has been shown to induce cell cycle arrest and apoptosis in cancer cells. Additionally, autophagy is a process that can lead to cell death. Therefore, it is possible that Psammaplin A induces autophagic cell death in cancer cells.
#
# Answer: Psammaplin A induces Sirtuin 1-dependent autophagic cell death in doxorubicin-resistant MCF-7/adr human breast cancer cells and xenografts.
#
# ---
#
# Context:
# [1] «This study examined links between DNA methylation and birth weight centile (BWC), and explored the impact of genetic variation. Using HumanMethylation450 arrays, we examined candidate gene-associated CpGs in cord blood from newborns with low (<15th centile), medium (40-60th centile) and high (>85th centile) BWC (n = 12). Candidates were examined in an investigation cohort (n = 110) using pyrosequencing and genotyping for putative methylation-associated polymorphisms performed using standard PCR. Array analysis identified 314 candidate genes associated with BWC extremes, four of which showed ≥ 4 BWC-linked CpGs. Of these, PM20D1 and MI886 suggested genetically determined methylation levels. However, methylation at three CpGs in FGFR2 remained significantly associated with high BWC (p = 0.004-0.027).»
# [2] «Studies performed in Andean populations living in high altitude, indicate that the reduced availability of oxygen could be associated to both a fetal growth retardation and a lower birth weight. These variables are predictive of morbidity and mortality during the first year of life. To study perinatal variables of newborns of mothers living at contrasting altitudinal levels, harboring different degrees of Aymara ancestry. Review of medical records of 5,295 women whose deliveries occurred between February 2004 and August 2010. Information was obtained on place of residence, grouped into two categories: coast (150 to 3,000 m) and high plateau (3,000 to 4,300 m), ancestry was estimated using number of Aymara surnames that were homologated to percentages of Amerindian admixture, gestational age, birth weight, height, head circumference and obstetric variables. Gestational age showed a tendency to increase and birth weight, height and head circumference to decrease with altitude of residence. Only weight reached statistical significance. Women with Aymara ancestry gave birth to children with a significantly higher gestational age, weight and cranial circumference.»
# [3] «Preterm delivery and sub-optimal fetal growth are associated with each other and affect both mother and infant. Our aim was to determine (i) whether there are detectable differences in DNA methylation between early and late gestation and (ii) whether changes in DNA methylation from entry are associated with spontaneous preterm delivery with and without reduced fetal growth. We conducted a case-control study nested within a large prospective cohort. Gene specific methylation was measured by Methyl-Profiler PCR Array in a Human Breast Cancer Signature Panel of 24 genes from maternal peripheral leukocytes genomic DNA at entry and 3 There was significantly decrease in DNA methylation in 15 of 24 genes during the 3»
#
# Question: Is methylation of the FGFR2 gene associated with high birth weight centile in humans?
#
# Reasoning: Let's think step by step in order to produce the answer. We know that the study identified 314 candidate genes associated with birth weight centile extremes, and found that methylation at three CpGs in FGFR2 remained significantly associated with high birth weight centile.
#
# Answer: Methylation of the FGFR2 gene is associated with high birth weight centile in humans.
#
# ---
#
# Context:
# [1] «Minimally invasive retroperitoneoscopic surgery (MIS) for psoas abscess (PA) in patients with thoracolumbar tuberculosis is not well-illustrated and has not reached the status of being fully clinically assessed when we review the English literatures. The aim of this study is to introduce and investigate on efficacy and feasibility of MIS (retroperitoneoscopic technique) for PA in patients with thoracolumbar tuberculosis. From January 2008 to 2013, 39 consecutive patients of the diagnosis of PA with thoracolumbar tuberculosis received the debridement of abscesses and cavity walls of abscesses by the retroperitoneoscopic technique (MIS) in combination with anti-tuberculosis chemotherapy. Medical records and follow-up data were retrospectively studied. CRP and ESR of every patient preoperatively and postoperatively were analyzed Immediate relief in clinical symptoms and signs, and amelioration in imaging and laboratory examinations were obviously observed in all the patients. The follow-up had proceeded for 12-48 (mean 23) months. No complication was observed during the follow-up postoperatively.»
# [2] «Current diagnostic tests for gastroesophageal reflux disease (GERD) do not consistently measure chronicity of reflux. Mucosal impedance (MI) is a minimally invasive measurement to assess esophageal conductivity changes due to GERD. We aimed to investigate MI pattern in patients with symptoms of extraesophageal reflux (EER) in a prospective longitudinal cohort study. Patients with potential symptoms of EER undergoing esophagogastroduodenoscopy (EGD) with wireless pH monitoring were studied. Participants included those with erosive esophagitis (E+), normal EGD/abnormal pH (E-/pH+), and normal EGD/normal pH (E-/pH-). MI was measured from the site of injury in patients with E+, as well as at 2, 5, and 10 cm above the squamocolumnar junction (SCJ) in all participants. Forty-one patients with symptoms of EER were studied. MI measurements at 2 cm above the SCJ were significantly (P = 0.04) different among the three groups, with MI lowest for E+ and greatest for E-/pH- patients. Although not statistically significant, there is a graded increase in median (interquartile range) MI axially along the esophagus at 5 cm (P = 0.20) and at 10 cm (P = 0.27) above the SCJ, with those with reflux (E+ and E-/pH+) having a lower MI than those without.»
# [3] «We evaluated the current role of minimally invasive surgery (MIS) in children with small bowel obstruction (SBO) at our institution. A retrospective review of patients undergoing MIS for acute SBO was performed from 2008 to 2013. The study population was compared with a historical control including patients from 2001 to 2008. There were 71 patients who met inclusion criteria; 35 were male, and 36 were female. Sixty-two children underwent laparoscopy for their first episode of SBO, and 12 underwent laparoscopy for recurrent SBO, accounting for 74 episodes of SBO managed with MIS. The most common etiology of SBO was adhesions (n=40). Laparoscopy and laparoscopic-assisted procedures were associated with shorter nasogastric tube decompression (1.4±2 days [P<.001] and 1.5±2.7 days [P=.002], respectively) and time to regular diet (3.9±4 days [P=.002] and 4.6±2.8 days [P=.024], respectively) compared with those converted to laparotomy (5.1±4.9 days of nasogastric tube decompressions and 8±4.7 days to regular diet). There was no difference in postoperative morbidity comparing laparoscopy (11%), laparoscopic-assisted (5%), and laparoscopic converted to open procedures (18%) (P=.48).»
#
# Question: Do minimally invasive retroperitoneoscopic surgery for psoas abscess with thoracolumbar tuberculosis?
#
# Reasoning: Let's think step by step in order to produce the answer. We know that the study aimed to introduce and investigate the efficacy and feasibility of minimally invasive retroperitoneoscopic surgery for psoas abscess in patients with thoracolumbar tuberculosis.
#
# Answer: Yes, minimally invasive retroperitoneoscopic surgery for psoas abscess in patients with thoracolumbar tuberculosis was found to be effective and feasible.
# "\n\n\nAnswer questions with short factoid answers.\n\n---\n\nQuestion: Do tumor-infiltrating immune cell profiles and their change after neoadjuvant chemotherapy predict response and prognosis of breast cancer?\nAnswer: Breast cancer immune cell subpopulation profiles, determined by immunohistochemistry-based computerized analysis, identify groups of patients characterized by high response (in the pre-treatment setting) and poor prognosis (in the post-treatment setting). Further understanding of the mechanisms underlying the distribution of immune cells and their changes after chemotherapy may contribute to the development of new immune-targeted therapies for breast cancer.\n\nQuestion: Do large portion sizes increase bite size and eating rate in overweight women?\nAnswer: Increasing portion size led to a larger bite size and faster eating rate, but a slower reduction in eating speed during the meal. These changes may underlie greater energy intakes with exposure to large portions. Interventions to reduce bite size and slow eating rate may provide individuals with strategies to reduce the risk of overconsumption.\n\nQuestion: Are secretory phospholipases A2 secreted from ciliated cells and increase mucin and eicosanoid secretion from goblet cells?\nAnswer: sPLA2 are secreted from ciliated cells and appear to induce mucin and cysLT secretion from goblet cells, strongly suggesting that airway goblet cells are proinflammatory effector cells.\n\nQuestion: Are reasons why erupted third molars extracted in a public university in Mexico?\nAnswer: Women and patients 18 to 34 years of age had erupted 3M extracted more frequently, primarily for prosthetic reasons. The age profile indicated a trend in demand for services that differ from those of overall tooth extractions, but not for the trend across gender.\n\nQuestion: Does increased Syk phosphorylation lead to overexpression of TRAF6 in peripheral B cells of patients with systemic lupus erythematosus?\nAnswer: Our results suggest that the activated Syk-mediated TRAF6 pathway leads to aberrant activation of B cells in SLE, and also highlight Syk as a potential target for B-cell-mediated processes in SLE.\n\nQuestion: Are routine preoperative restaging CTs after neoadjuvant chemoradiation for locally advanced rectal cancer low yield : a retrospective case study?\nAnswer: Because of the financial costs and established risks of intravenous contrast and cumulative radiation exposure, it may be advisable to take a more selective approach to preoperative imaging. Larger, prospective studies may enable identification of an at-risk cohort who would benefit most from restaging CT.\n\nQuestion: Does the Boston keratoprosthesis provide a wide depth of focus?\nAnswer: The KPro's wide depth-of-focus makes the visual acuity less dependent on an exact refractive correction at distance and explains the 'pseudoaccomodation' experienced by these patients. This is primarily due to the small pupil diameter of the KPro. The current manufacturing steps in 0.50 dioptre increments appears to be sufficient.\n\nQuestion: Do obese patients with idiopathic pulmonary fibrosis have a higher 90-day mortality risk with bilateral lung transplantation?\nAnswer: Our results suggest that obese patients who receive a BLT may be at higher risk of 90-day mortality compared with patients of normal weight. Further study is needed to obtain more detailed information about comorbidities and other risk factors for early death that are not included in the OPTN database.\n\nQuestion: Is admission hyperglycemia associated with failed reperfusion following fibrinolytic therapy in patients with STEMI : results of a retrospective study?\nAnswer: In patients with STEMI who undergo FT, admission hyperglycemia is an independent predictor of the failure of fibrinolysis.\n\nQuestion: Is hidradenitis suppurativa a systemic disease with substantial comorbidity burden : a chart-verified case-control analysis?\nAnswer: Control subjects were  ...

# %% [markdown]
# ## Optimized Haystack Pipeline
#
# We can now use the static part of the optimized prompt (including examples) and create a better Haystack RAG Pipeline.
#
# We include an `AnswerBuilder`, to capture only the relevant part of the generation (all text after `Answer: `).

# %%
# %%capture

static_prompt = lm.inspect_history(n=1).rpartition("---\n")[0]

# %%
print(static_prompt)
# Out:
# Answer questions with short factoid answers.
#
# ---
#
# Question: Do tumor-infiltrating immune cell profiles and their change after neoadjuvant chemotherapy predict
# response and prognosis of breast cancer?
# Answer: Breast cancer immune cell subpopulation profiles, determined by immunohistochemistry-based computerized
# analysis, identify groups of patients characterized by high response (in the pre-treatment setting) and poor
# prognosis (in the post-treatment setting). Further understanding of the mechanisms underlying the distribution of
# immune cells and their changes after chemotherapy may contribute to the development of new immune-targeted
# therapies for breast cancer.
#
# Question: Do large portion sizes increase bite size and eating rate in overweight women?
# Answer: Increasing portion size led to a larger bite size and faster eating rate, but a slower reduction in eating
# speed during the meal. These changes may underlie greater energy intakes with exposure to large portions.
# Interventions to reduce bite size and slow eating rate may provide individuals with strategies to reduce the risk
# of overconsumption.
#
# Question: Are secretory phospholipases A2 secreted from ciliated cells and increase mucin and eicosanoid secretion
# from goblet cells?
# Answer: sPLA2 are secreted from ciliated cells and appear to induce mucin and cysLT secretion from goblet cells,
# strongly suggesting that airway goblet cells are proinflammatory effector cells.
#
# Question: Are reasons why erupted third molars extracted in a public university in Mexico?
# Answer: Women and patients 18 to 34 years of age had erupted 3M extracted more frequently, primarily for prosthetic
# reasons. The age profile indicated a trend in demand for services that differ from those of overall tooth
# extractions, but not for the trend across gender.
#
# Question: Does increased Syk phosphorylation lead to overexpression of TRAF6 in peripheral B cells of patients with
# systemic lupus erythematosus?
# Answer: Our results suggest that the activated Syk-mediated TRAF6 pathway leads to aberrant activation of B cells
# in SLE, and also highlight Syk as a potential target for B-cell-mediated processes in SLE.
#
# Question: Are routine preoperative restaging CTs after neoadjuvant chemoradiation for locally advanced rectal
# cancer low yield : a retrospective case study?
# Answer: Because of the financial costs and established risks of intravenous contrast and cumulative radiation
# exposure, it may be advisable to take a more selective approach to preoperative imaging. Larger, prospective
# studies may enable identification of an at-risk cohort who would benefit most from restaging CT.
#
# Question: Does the Boston keratoprosthesis provide a wide depth of focus?
# Answer: The KPro's wide depth-of-focus makes the visual acuity less dependent on an exact refractive correction at
# distance and explains the 'pseudoaccomodation' experienced by these patients. This is primarily due to the small
# pupil diameter of the KPro. The current manufacturing steps in 0.50 dioptre increments appears to be sufficient.
#
# Question: Do obese patients with idiopathic pulmonary fibrosis have a higher 90-day mortality risk with bilateral
# lung transplantation?
# Answer: Our results suggest that obese patients who receive a BLT may be at higher risk of 90-day mortality
# compared with patients of normal weight. Further study is needed to obtain more detailed information about
# comorbidities and other risk factors for early death that are not included in the OPTN database.
#
# Question: Is admission hyperglycemia associated with failed reperfusion following fibrinolytic therapy in patients
# with STEMI : results of a retrospective study?
# Answer: In patients with STEMI who undergo FT, admission hyperglycemia is an independent predictor of the failure
# of fibrinolysis.
#
# Question: Is hidradenitis suppurativa a systemic disease with substantial comorbidity burden : a chart-verified
# case-control analysis?
# Answer: Control subjects were not validated for absence of HS and comorbidity validation was not performed for
# either group.
#
# Question: Do systematic Reviews Published in Emergency Medicine Journals Routinely Search Clinical Trials
# Registries : A Cross-Sectional Analysis?
# Answer: Systematic reviews published in emergency medicine journals do not routinely include searches of clinical
# trials registries. By helping authors identify unpublished trial data, the addition of registry searches may
# improve the validity of systematic reviews.
#
# Question: Does promoter variant rs2301228 on the neural cell adhesion molecule 1 gene confer risk of schizophrenia
# in Han Chinese?
# Answer: Our results provide direct evidence for NCAM1 as a susceptibility gene for schizophrenia, which offers
# support to a neurodevelopmental model and neuronal connectivity hypothesis in the onset of schizophrenia.
#
# ---
#
# Follow the following format.
#
# Context: may contain relevant facts
#
# Question: ${question}
#
# Reasoning: Let's think step by step in order to ${produce the answer}. We ...
#
# Answer: short and precise answer
#
# ---
#
# Context:
# [1] «Chronic rhinosinusitis (CRS) is a heterogeneous disease with an uncertain pathogenesis. Group 2 innate
# lymphoid cells (ILC2s) represent a recently discovered cell population which has been implicated in driving Th2
# inflammation in CRS; however, their relationship with clinical disease characteristics has yet to be investigated.
# The aim of this study was to identify ILC2s in sinus mucosa in patients with CRS and controls and compare ILC2s
# across characteristics of disease. A cross-sectional study of patients with CRS undergoing endoscopic sinus surgery
# was conducted. Sinus mucosal biopsies were obtained during surgery and control tissue from patients undergoing
# pituitary tumour resection through transphenoidal approach. ILC2s were identified as CD45(+) Lin(-) CD127(+) CD4(-)
# CD8(-) CRTH2(CD294)(+) CD161(+) cells in single cell suspensions through flow cytometry. ILC2 frequencies, measured
# as a percentage of CD45(+) cells, were compared across CRS phenotype, endotype, inflammatory CRS subtype and other
# disease characteristics including blood eosinophils, serum IgE, asthma status and nasal symptom score. 35 patients
# (40% female, age 48 ± 17 years) including 13 with eosinophilic CRS (eCRS), 13 with non-eCRS and 9 controls were
# recruited. ILC2 frequencies were associated with the presence of nasal polyps (P = 0.002) as well as high tissue
# eosinophilia (P = 0.004) and eosinophil-dominant CRS (P = 0.001) (Mann-Whitney U). They were also associated with
# increased blood eosinophilia (P = 0.005). There were no significant associations found between ILC2s and serum
# total IgE and allergic disease. In the CRS with nasal polyps (CRSwNP) population, ILC2s were increased in patients
# with co-existing asthma (P = 0.03). ILC2s were also correlated with worsening nasal symptom score in CRS (P =
# 0.04).»
# [2] «Allergic airway inflammation is triggered by allergen exposure through several steps including release of
# IL-33, which promotes cytokine (IL-5, IL-13) production by type 2 innate lymphoid cells (ILC2s). MicroRNA (miR)-155
# has recently been described to regulate adaptive responses in allergic inflammation. However, the role of miR-155
# in the regulation of ILC2s remains unexplored. We sought to elucidate the contribution of miR-155 in ILC2 expansion
# using experimental murine models of allergic airway inflammation. To determine the role of miR-155 in the
# regulation of ILC2s in allergic airway inflammation, miR-155 deficient (miR-155 miR-155 was 10-fold upregulated in
# WT-derived ILC2s in response to IL-33. Furthermore, miR-155»
# [3] «The mechanisms and immune pathways associated with chronic rhinosinusitis (CRS) are not fully understood.
# Immunological changes during acute exacerbation of CRS may provide valuable clues to the pathogenesis and
# perpetuation of the disease. To characterize local and systemic immune responses associated with acute worsening of
# sinonasal symptoms during exacerbation in CRS with nasal polyps (CRSwNP) compared to controls. This was a
# non-interventional prospective study of individuals with CRSwNP and normal controls. Subjects underwent a baseline
# visit with collection of nasal secretions, nasal washes, and serum specimens. Within 3 days of acute worsening of
# sinonasal symptoms, subjects underwent a study visit, followed by a post-visit 2 weeks later. The sinonasal outcome
# test-22 (SNOT-22) scores and immunological parameters in the specimens were analysed using a novel, unsupervised
# learning method and by conventional univariate analysis. Both CRSwNP patients and control subjects showed a
# significant increase in SNOT-22 scores during acute exacerbation. Increased nasal levels of IL-6, IL-5, and
# eosinophil major basic protein were observed in CRSwNP patients. A network analysis of serum specimens revealed
# changes in a set of immunological parameters, which are distinctly associated with CRSwNP but not with controls. In
# particular, systemic increases in VEGF and GM-CSF levels were notable and were validated by a conventional
# analysis.»
#
# Question: Are group 2 innate lymphoid cells ( ILC2s ) increased in chronic rhinosinusitis with nasal polyps or
# eosinophilia?
#
# Reasoning: Let's think step by step in order to produce the answer. We have data from a study that compared ILC2
# frequencies in patients with CRS with nasal polyps or eosinophilia to controls.
#
# Answer: Yes, ILC2 frequencies were found to be increased in patients with chronic rhinosinusitis with nasal polyps
# and eosinophilia.
#
# ---
#
# Context:
# [1] «Phosphatidylethanolamine N-methyltransferase (PEMT), a liver enriched enzyme, is responsible for approximately
# one third of hepatic phosphatidylcholine biosynthesis. When fed a high-fat diet (HFD), Pemt(-/-) mice are protected
# from HF-induced obesity; however, they develop steatohepatitis. The vagus nerve relays signals between liver and
# brain that regulate peripheral adiposity and pancreas function. Here we explore a possible role of the hepatic
# branch of the vagus nerve in the development of diet induced obesity and steatohepatitis in Pemt(-/-) mice. 8-week
# old Pemt(-/-) and Pemt(+/+) mice were subjected to hepatic vagotomy (HV) or capsaicin treatment, which selectively
# disrupts afferent nerves, and were compared to sham-operated or vehicle-treatment, respectively. After surgery,
# mice were fed a HFD for 10 weeks. HV abolished the protection against the HFD-induced obesity and glucose
# intolerance in Pemt(-/-) mice. HV normalized phospholipid content and prevented steatohepatitis in Pemt(-/-) mice.
# Moreover, HV increased the hepatic anti-inflammatory cytokine interleukin-10, reduced chemokine monocyte
# chemotactic protein-1 and the ER stress marker C/EBP homologous protein. Furthermore, HV normalized the expression
# of mitochondrial electron transport chain proteins and of proteins involved in fatty acid synthesis, acetyl-CoA
# carboxylase and fatty acid synthase in Pemt(-/-) mice. However, disruption of the hepatic afferent vagus nerve by
# capsaicin failed to reverse either the protection against the HFD-induced obesity or the development of HF-induced
# steatohepatitis in Pemt(-/-) mice.»
# [2] «Nonalcoholic steatohepatitis (NASH) is associated with cirrhosis and hepatocellular carcinoma. Reactive oxygen
# species (ROS) and reactive nitrogen species (RNS) play key roles in the development of the disease. However, the
# therapeutic target of NASH has not been fully defined and new treatments are needed. We investigated the protective
# effects of the antioxidant indole-derived NecroX-7 in a NASH mouse model using leptin-deficient ob/ob and
# methionine- and choline-deficient (MCD) diet-fed ob/ob mice. Six-week-old male mice were divided into three groups:
# ob/+ mice, ob/ob mice treated with vehicle and ob/ob mice treated daily with NecroX-7 (20 mg/kg) for 4 weeks. To
# study the effects of NecroX-7 in a fibrosis model, NASH was induced by feeding ob/ob mice an MCD diet. The effects
# of NecroX-7 on NASH progression were evaluated using biochemical, histological and molecular markers.
# NecroX-7-treated ob/ob mice had a marked decrease in serum aspartate aminotransferase and alanine transaminase
# compared with vehicle-treated controls. Interestingly, hepatic steatosis and lipid peroxidation were significantly
# improved by NecroX-7 treatment. NecroX-7 inhibited tert-butylhydroperoxide- and H2 O2 -induced mitochondrial
# ROS/RNS in primary hepatocytes and attenuated mitochondrial dysfunction in vitro and in vivo. Furthermore,
# NecroX-7-treated mice exhibited fewer infiltrating macrophages and reduced hepatic tumour necrosis factor-alpha
# expression. Hepatic fibrosis in MCD-fed ob/ob mice was significantly decreased by NecroX-7 treatment.»
# [3] «The ability of a treatment method to interfere with tinnitus-related neural activity patterns, such as
# cortical gamma rhythms, has been suggested to indicate its potential in relieving tinnitus. Therapeutic modulation
# of gamma-band oscillations with vagus nerve stimulation has been recently reported in epileptic patients. The aim
# of this study was to investigate the effects of transcutaneous vagus nerve stimulation (tVNS) on neural oscillatory
# patterns. We calculated the power spectral density and synchrony of magnetoencephalography recordings during
# auditory stimulation in seven tinnitus patients and eight normal-hearing control subjects. Comparisons between
# subject groups were performed to reveal electrophysiological markers of tinnitus. tVNS-specific effects within each
# group were studied by comparing recording blocks with and without tVNS. We also investigated the correlation of
# each measure with individual ratings of tinnitus distress, as measured by the tinnitus handicap inventory
# questionnaire. Tinnitus patients differed from controls in the baseline condition (no tVNS applied), measured by
# both cortical oscillatory power and synchronization, particularly at beta and gamma frequencies. Importantly, we
# found tVNS-induced changes in synchrony, correlating strongly with tinnitus handicap inventory scores, at
# whole-head beta-band (r = -0.857, p = 0.007), whole-head gamma-band (r = -0.952, p = 0.0003), and frontal
# gamma-band (r = -0.952, p = 0.0003).»
#
# Question: Does vagus nerve contribute to the development of steatohepatitis and obesity in phosphatidylethanolamine
# N-methyltransferase deficient mice?
#
# Reasoning: Let's think step by step in order to produce the answer. We need to understand the role of the vagus
# nerve in the development of steatohepatitis and obesity in Pemt(-/-) mice.
#
# Answer: Yes, the hepatic branch of the vagus nerve contributes to the development of diet-induced obesity and
# steatohepatitis in Pemt(-/-) mice.
#
# ---
#
# Context:
# [1] «Psammaplin A (PsA) is a natural product isolated from marine sponges, which has been demonstrated to have
# anticancer activity against several human cancer cell lines via the induction of cell cycle arrest and apoptosis.
# New drugs that are less toxic and more effective against multidrug-resistant cancers are urgently needed. We tested
# cell proliferation, cell cycle progression and autophagic cell death pathway in doxorubicin-resistant MCF-7
# (MCF-7/adr) human breast cancer cells. The potency of PsA was further determined using an in vivo xenograft model.»
# [2] «The purpose of this study was to investigate the relationship between huntingtin-associated protein1 (HAP1)
# gene and radiation therapy of breast cancer cells. HAP1 gene was transfected into breast cancer MCF-7 cells, which
# was confirmed by quantitative reverse transcription-polymerase chain reaction analysis (qRT-PCR) and Western blot
# in vitro. The changes of cell radiosensitivity were assessed by colony formation assay. Apoptosis were examined by
# flow cytometry. The expressions of two radiation-induced genes were evaluated by Western blot. Tumor growth was
# investigated in nude mice xenograft models in vivo. Our data showed that HAP1 gene expression was significantly
# increased in HAP1-transfected MCF-7 cells in comparison with the parental cells or negative control cells. The
# survival rate in MCF-7/HAP1 cells was significantly decreased after irradiation (0, 2, 4, 6, 8Gy), compared to
# cells in MCF-7 and MCF-7/Pb groups in vitro. HAP1 gene increased apoptosis in MCF-7 cells after irradiation.
# Additionally, the tumor volume and weight in MCF-7/HAP1+RT group were observably lower than in MCF-7/HAP1 group and
# MCF-7/Pb+RT group.»
# [3] «Due to the chemo resistant nature of cancer cells and adverse effects of current therapies, researchers are
# looking for the most efficient therapeutic approach which has the lowest side effects and the highest toxicity on
# cancer cells. The aim of the present study was to investigate the synergic effect of Urtica dioica extract in
# combination with paclitaxel on cell death and invasion of human breast cancer MDA-MB-468 cell line. To determine
# the cytotoxic effects of Urtica dioica extract with paclitaxel, MTT assay was performed. The scratch test was
# exploited to assess the effects of Urtica dioica, Paclitaxel alone and combination on migration of cancer cells.
# The expression levels of snail-1, ZEB1, ZEB2, twist, Cdc2, cyclin B1 and Wee1 genes were quantified using qRT-PCR
# and western blot performed for snail-1expression. The effects of plant extract, Paclitaxel alone and combination on
# different phases of cell cycle was analyzed using flow cytometry. Results of MTT assay showed that Urtica dioica
# significantly destroyed cancer cells. Interestingly, Concurrent use of Urtica dioica extract with paclitaxel
# resulted in decreased IC50 dose of paclitaxel. Moreover, findings of scratch assay exhibited the inhibitory effects
# of Urtica dioica, Paclitaxel alone and combination on migration of MDA-MB-468 cell line. Our findings also
# demonstrated that the extract substantially decreased the Snail-1 and related gene expression. Ultimately, Cell
# cycle arrest occurred at G2/M phase post-treatment by deregulating Cdc2 and wee1.»
#
# Question: Does psammaplin A induce Sirtuin 1-dependent autophagic cell death in doxorubicin-resistant MCF-7/adr
# human breast cancer cells and xenografts?
#
# Reasoning: Let's think step by step in order to produce the answer. We know that Psammaplin A has been shown to
# induce cell cycle arrest and apoptosis in cancer cells. Additionally, autophagy is a process that can lead to cell
# death. Therefore, it is possible that Psammaplin A induces autophagic cell death in cancer cells.
#
# Answer: Psammaplin A induces Sirtuin 1-dependent autophagic cell death in doxorubicin-resistant MCF-7/adr human
# breast cancer cells and xenografts.
#
# ---
#
# Context:
# [1] «This study examined links between DNA methylation and birth weight centile (BWC), and explored the impact of
# genetic variation. Using HumanMethylation450 arrays, we examined candidate gene-associated CpGs in cord blood from
# newborns with low (<15th centile), medium (40-60th centile) and high (>85th centile) BWC (n = 12). Candidates were
# examined in an investigation cohort (n = 110) using pyrosequencing and genotyping for putative
# methylation-associated polymorphisms performed using standard PCR. Array analysis identified 314 candidate genes
# associated with BWC extremes, four of which showed ≥ 4 BWC-linked CpGs. Of these, PM20D1 and MI886 suggested
# genetically determined methylation levels. However, methylation at three CpGs in FGFR2 remained significantly
# associated with high BWC (p = 0.004-0.027).»
# [2] «Studies performed in Andean populations living in high altitude, indicate that the reduced availability of
# oxygen could be associated to both a fetal growth retardation and a lower birth weight. These variables are
# predictive of morbidity and mortality during the first year of life. To study perinatal variables of newborns of
# mothers living at contrasting altitudinal levels, harboring different degrees of Aymara ancestry. Review of medical
# records of 5,295 women whose deliveries occurred between February 2004 and August 2010. Information was obtained on
# place of residence, grouped into two categories: coast (150 to 3,000 m) and high plateau (3,000 to 4,300 m),
# ancestry was estimated using number of Aymara surnames that were homologated to percentages of Amerindian
# admixture, gestational age, birth weight, height, head circumference and obstetric variables. Gestational age
# showed a tendency to increase and birth weight, height and head circumference to decrease with altitude of
# residence. Only weight reached statistical significance. Women with Aymara ancestry gave birth to children with a
# significantly higher gestational age, weight and cranial circumference.»
# [3] «Preterm delivery and sub-optimal fetal growth are associated with each other and affect both mother and
# infant. Our aim was to determine (i) whether there are detectable differences in DNA methylation between early and
# late gestation and (ii) whether changes in DNA methylation from entry are associated with spontaneous preterm
# delivery with and without reduced fetal growth. We conducted a case-control study nested within a large prospective
# cohort. Gene specific methylation was measured by Methyl-Profiler PCR Array in a Human Breast Cancer Signature
# Panel of 24 genes from maternal peripheral leukocytes genomic DNA at entry and 3 There was significantly decrease
# in DNA methylation in 15 of 24 genes during the 3»
#
# Question: Is methylation of the FGFR2 gene associated with high birth weight centile in humans?
#
# Reasoning: Let's think step by step in order to produce the answer. We know that the study identified 314 candidate
# genes associated with birth weight centile extremes, and found that methylation at three CpGs in FGFR2 remained
# significantly associated with high birth weight centile.
#
# Answer: Methylation of the FGFR2 gene is associated with high birth weight centile in humans.

# %%
from haystack.components.retrievers.in_memory import InMemoryBM25Retriever
from haystack.components.generators import OpenAIGenerator
from haystack.components.builders import PromptBuilder, AnswerBuilder
from haystack import Pipeline


template = static_prompt+"""
---

Context:
{% for document in documents %}
    «{{ document.content }}»
{% endfor %}

Question: {{question}}
Reasoning: Let's think step by step in order to
"""

new_prompt_builder = PromptBuilder(template=template)

new_retriever = InMemoryBM25Retriever(document_store, top_k=3)
new_generator = OpenAIGenerator(model="gpt-3.5-turbo")

answer_builder = AnswerBuilder(pattern="Answer: (.*)")


optimized_rag_pipeline = Pipeline()
optimized_rag_pipeline.add_component("retriever", new_retriever)
optimized_rag_pipeline.add_component("prompt_builder", new_prompt_builder)
optimized_rag_pipeline.add_component("llm", new_generator)
optimized_rag_pipeline.add_component("answer_builder", answer_builder)

optimized_rag_pipeline.connect("retriever", "prompt_builder.documents")
optimized_rag_pipeline.connect("prompt_builder", "llm")
optimized_rag_pipeline.connect("llm.replies", "answer_builder.replies")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x0000027756C48C40>
# 🚅 Components
#   - retriever: InMemoryBM25Retriever
#   - prompt_builder: PromptBuilder
#   - llm: OpenAIGenerator
#   - answer_builder: AnswerBuilder
# 🛤️ Connections
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)
#   - llm.replies -> answer_builder.replies (List[str])

# %% [markdown]
# Let's ask the same questions as before...

# %%
question = "What effects does ketamine have on rat neural stem cells?"

response = optimized_rag_pipeline.run({"retriever": {"query": question}, "prompt_builder": {"question": question}, "answer_builder": {"query": question}})

print(response["answer_builder"]["answers"][0].data)
# Out:
# Ketamine at concentrations of 200, 500, 800, and 1000μM significantly inhibited the proliferation of rat neural
# stem cells and decreased intracellular calcium concentration.

# %%
question = "Is the anterior cingulate cortex linked to pain-induced depression?"
response = optimized_rag_pipeline.run({"retriever": {"query": question}, "prompt_builder": {"question": question}, "answer_builder": {"query": question}})

print(response["answer_builder"]["answers"][0].data)
# Out:
# Yes, the anterior cingulate cortex is linked to pain-induced depression.

# %% [markdown]
# The answer are correct and shorter than before!

# %% [markdown]
# *(Notebook by [Stefano Fiorucci](https://github.com/anakin87))*
